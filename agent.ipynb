# %%
import sys
# !{sys.executable} -m pip install -qU langchain-huggingface
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install -U langchain langchain-core
# Out:
# Requirement already satisfied: langchain in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (1.0.1)
# Requirement already satisfied: langchain-core in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (1.0.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langchain) (1.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langchain) (2.12.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langchain-core) (0.4.37)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langchain-core) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.1.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.1.0,>=1.0.0->langchain) (2.1.2)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.1.0,>=1.0.0->langchain) (1.0.0)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.1.0,>=1.0.0->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.1.0,>=1.0.0->langchain) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: anyio in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (4.11.0)
# Requirement already satisfied: certifi in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: idna in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.0->langchain) (1.11.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from owlready2 import get_ontology, Thing, Restriction, And, Or, Not
from langchain_core.documents import Document
from owlready2 import FunctionalProperty, InverseFunctionalProperty, TransitiveProperty, SymmetricProperty, AsymmetricProperty, ReflexiveProperty, IrreflexiveProperty

def ontology_to_vector_store(onto, llm, vector_store):

    #convert restriction into text
    def restriction_to_text(restriction):

        #get name of property the restriction applies to
        #if property is None fallback to string, this shouldnt happen, but just incase 
        prop_name = restriction.property.name if restriction.property else str(restriction.property)

        # Check for "exists" attribute
        if hasattr(restriction, "some_values_from") and restriction.some_values_from: #check attribute and not empty
            #get name from target class or fallback to object itself
            target = getattr(restriction.some_values_from, "name", restriction.some_values_from)
            return f"must have some {prop_name} from {target}"
        
        # Check for "all" attribute
        elif hasattr(restriction, "all_values_from") and restriction.all_values_from:
            target = getattr(restriction.all_values_from, "name", restriction.all_values_from)
            return f"can only have {prop_name} from {target}"
        
        # Check for "≥" attribute
        elif hasattr(restriction, "min_cardinality") and restriction.min_cardinality is not None: #add is not None, because "0" would be handled as False
            return f"{prop_name} ≥ {restriction.min_cardinality}"
        
        # Check for "≤" attribute
        elif hasattr(restriction, "max_cardinality") and restriction.max_cardinality is not None: #add is not None, because "0" would be handled as False
            return f"{prop_name} ≤ {restriction.max_cardinality}"
        
        #Fallback for other types of restrictions
        else:
            return f"{prop_name} with unknown restriction {restriction}"

    #recursive function that turns expression to text
    def expression_to_text(expr):

        #Ontology class
        if hasattr(expr, "name"):
            return expr.name
        
        #constraint in ontology
        elif isinstance(expr, Restriction):
            return restriction_to_text(expr)
        
        #And expression
        elif isinstance(expr, And):
            return " and ".join(expression_to_text(c) for c in expr.Classes)
        
        #Or expression
        elif isinstance(expr, Or):
            return " or ".join(expression_to_text(c) for c in expr.Classes)
        
        #Not expr
        elif isinstance(expr, Not):
            return f"not {expression_to_text(expr.Class)}"

        #Fallback, return string
        else:
            return str(expr)

    #turns ontology class to text
    def class_to_text(cls):
        lines = [f"The class {cls.name} is defined as follows:"]
        
        # Superclasses
        for parent in cls.is_a:
            lines.append(f"- Subclass of {expression_to_text(parent)}")
        
        # Equivalent classes
        for eq in cls.equivalent_to:
            lines.append(f"- Equivalent to {expression_to_text(eq)}")
        
        return "\n".join(lines)

    # turn object or data property to text
    def property_to_text(prop):
        #starting text
        lines = [f"The property {prop.name} is defined as follows:"]
        
        #check for "domain" attribute and not empty
        if hasattr(prop, "domain") and prop.domain:
            #convert each class in domain to text
            domain_text = ", ".join(expression_to_text(d) for d in prop.domain)
            lines.append(f"- Domain: {domain_text}")
        
        #check for "range" attribute and not empty
        if hasattr(prop, "range") and prop.range:
            #convert each class in range to text
            range_text = ", ".join(expression_to_text(r) for r in prop.range)
            lines.append(f"- Range: {range_text}")
        
        # Only include characteristics if they exist
        if issubclass(prop, FunctionalProperty):
            lines.append("- This property is functional (at most one value).")
        if issubclass(prop, InverseFunctionalProperty):
            lines.append("- This property is inverse functional (each value has at most one subject).")
        if issubclass(prop, TransitiveProperty):
            lines.append("- This property is transitive.")
        if issubclass(prop, SymmetricProperty):
            lines.append("- This property is symmetric.")
        if issubclass(prop, AsymmetricProperty):
            lines.append("- This property is asymmetric.")
        if issubclass(prop, ReflexiveProperty):
            lines.append("- This property is reflexive (every individual is related to itself).")
        if issubclass(prop, IrreflexiveProperty):
            lines.append("- This property is irreflexive (no individual is related to itself).")
        
        return "\n".join(lines)

    # turn instances to text
    def instance_to_text(instance):
        lines = [f"The instance {instance.name} is defined as follows:"]

        # Classes this instance belongs to
        types = [cls.name for cls in instance.is_a if hasattr(cls, "name")]
        if types:
            lines.append(f"- Belongs to class(es): {', '.join(types)}")

        # All properties (object and data) that this individual actually has
        for prop in instance.get_properties():
            try:
                values = getattr(instance, prop.python_name, [])
            except Exception:
                continue
            if values:
                # make iterable if not
                if not isinstance(values, (list, tuple, set)):
                    values = [values]
                # check if each value has a name (object property) or is literal (data property)
                values_text = ", ".join(getattr(v, "name", str(v)) for v in values)
                lines.append(f"- {prop.name}: {values_text}")

        return "\n".join(lines)

    # Collect all text for LLM
    ontology_texts = []

    # Add text for Classes
    for cls in onto.classes():
        #print(cls)
        ontology_texts.append(class_to_text(cls))

    # Add text for Object and datatype properties
    for prop in onto.object_properties():
        ontology_texts.append(property_to_text(prop))
    for prop in onto.data_properties():
        ontology_texts.append(property_to_text(prop))

    # Add text for instances
    for instance in onto.individuals():
        ontology_texts.append(instance_to_text(instance)) 

    # Turn into LLM documents
    docs = []
    for text in ontology_texts:
        prompt = (
            "Convert the following ontology snippet into clear, human-readable English.\n"
            f"Snippet: {text}\n\n"
            "Do not add external information or commentary. Only describe what is present. Do not include any \"Here is a snippet\" to the output"
        )
        human_text = llm.invoke(prompt)
        print(human_text.content)
        docs.append(Document(page_content=human_text.content))

    # Add to your vector store
    vector_store.add_documents(docs)
    return vector_store

# %%
def scenario_splitter_llm(story, llm):
    story_to_scenarios_prompt = f"""
    You are an assistant that extracts logical or factual scenarios from a given story.

    A scenario is a small, self-contained statement or short passage that expresses one or more closely related facts, events, or claims that can later be checked for correctness or consistency using an ontology.
    ---

    ### Guidelines:
    - Each scenario should capture a complete idea, including all details that are logically connected (for example, cause–effect, contrast, or relationship).
    - If two or more statements are relevant to each other (e.g., one qualifies, contradicts, or explains the other), combine them into one scenario.
    - Preserve contextual and relational details - who, what, where, when, and why.
    - Avoid redundancy - do not restate the same information.
    - Keep each scenario brief but complete (usually one to three sentences).
    - Include implicit facts when they are important (e.g., “John’s wife Amira” implies John is married to Amira).
    - Ensure that every piece of relevant information from the story appears in at least one scenario.

    ---

    Example

    Story:
    “John is 15 years old and is on vacation with his wife Amira in Italy. Their daughter Anna can’t wait to visit the Eiffel Tower.”

    Extracted Scenarios:
    1. John is 15 years old and is married to Amira.
    2. John and Amira are on vacation in Italy.
    3. John and Amira have a daughter named Anna.
    4. Anna wants to visit the Eiffel Tower.

    ---

    Now extract the scenarios from the following story and number them clearly:

    {story}
    """

    # Query the LLM
    response = llm.invoke(story_to_scenarios_prompt)
    if hasattr(response, "content"):  # LangChain AIMessage
        output_text = response.content
    elif isinstance(response, dict) and "content" in response:
        output_text = response["content"]
    elif isinstance(response, str):
        output_text = response
    else:
        raise TypeError(f"Unexpected LLM response type: {type(response)}")

    # Extract list items using regex
    import re
    scenarios = re.findall(r'(?:\d+\.\s*)(.+)', output_text)
    scenarios = [s.strip() for s in scenarios if s.strip()]

    # If the LLM doesnt number them, fallback to line splitting
    if not scenarios:
        scenarios = [line.strip("-• \t") for line in output_text.splitlines() if line.strip()]

    return scenarios

# %%
from typing import List, Dict, Any
from langchain_core.prompts import PromptTemplate

#fixes scenarios incrementally using ontology to reason. Ensures each fix remains consistent with previous scenario updates
def fix_scenarios_incrementally(scenarios: List[str], vector_store, llm, prompt_template: PromptTemplate, k):

    updated_scenarios = []
    accumulated_story = "" #Used as reasoning context for the next step
    results = []

    for i, scenario in enumerate(scenarios, start=1):
        #Retrieve ontology documents relevant to current scenario (RAG)
        retrieved_docs = vector_store.similarity_search(scenario, k=k)
        ontology_text = "\n\n".join(doc.page_content for doc in retrieved_docs)

        #Make context with ontology + story so far
        full_context = (
            f"Ontology context:\n{ontology_text}\n\n"
            f"Story so far:\n{accumulated_story.strip() or '(none so far)'}\n"
        )

        #Make the prompt using the template
        rendered_prompt = prompt_template.format(
            question=scenario.strip(),
            context=full_context.strip(),
        )

        #Invoke the model
        llm_response = llm.invoke(rendered_prompt)
        response_text = llm_response.content.strip()

        #Parse model output
        updated_scenario = scenario
        consistency = "Unknown"
        explanation_lines = []

        for line in response_text.splitlines():
            lowered_line = line.lower().strip()
            if lowered_line.startswith("consistency:"):
                consistency = line.split(":", 1)[1].strip()#Split at first ":" only and take everything after it. Example: consistency: consistent, we only want 2nd part
                in_explanation = False
            elif lowered_line.startswith("updated scenario:"):
                updated_scenario = line.split(":", 1)[1].strip()#Split at first ":" only and take everything after it.
                in_explanation = False
            elif lowered_line.startswith("explanation:"):
                #begin collecting explanation text
                after = line.split(":", 1)[1].strip()#Split at first ":" only and take everything after it.
                if after:
                    explanation_lines.append(after)
                in_explanation = True
            #if just a line and last line was explanation. (This is next sentence of explanation)
            else:
                if in_explanation:
                    explanation_lines.append(line) #Add next sentence of explanation

        #Convert explanation into single string
        explanation = "\n".join(explanation_lines).strip()

        #Update accumulated story so future reasoning uses this to fix scenarios
        accumulated_story = (accumulated_story + "\n" + updated_scenario).strip()
        updated_scenarios.append(updated_scenario)

        #Store result for logging or later evaluation
        results.append({
            "step": i,
            "original": scenario,
            "updated": updated_scenario,
            "consistency": consistency,
            "ontology_used": ontology_text.strip(),
            "llm_raw_output": response_text.strip(),
            "explanation": explanation,
            "story_so_far": accumulated_story.strip()
        })

    return updated_scenarios, results

# %%
from langchain_core.prompts import PromptTemplate

scenario_fixing_prompt = PromptTemplate.from_template("""
You are a reasoning assistant that checks whether each part of a story (called a 'scenario')
is logically consistent with (a) the ontology information provided and (b) the previously verified parts of the story.

You are given:
1. Ontology context - short human-readable snippets extracted from an ontology (classes, restrictions, domains/ranges, instances).
2. Story so far - previously verified or corrected parts of the story.
3. A new scenario - the next statement to evaluate.

Your tasks (use only the provided ontology context and story so far; do NOT use external world knowledge):
- Determine whether the new scenario is consistent with BOTH the ontology context and the story so far.
- If inconsistent, rewrite the scenario minimally to make it consistent.
- Explain, concisely and step-by-step, which ontology facts (from the provided context) you used and why the original scenario was inconsistent or consistent.
- If you changed the scenario, explain which minimal change you made and why that resolves the inconsistency.
- Prefer small, natural edits that preserve meaning and story flow.

**STRICT OUTPUT FORMAT (must follow exactly)**

Consistency: [Consistent / Inconsistent]

Updated scenario: [Corrected or unchanged scenario; if unchanged, copy the original. DO NOT OUTPUT "No change" or "unchanged"]

Explanation:
[A short, numbered or bulleted explanation (1-4 sentences) describing:
 - which ontology statements you used (quote or paraphrase them),
 - why the scenario is or is not consistent,
 - and, if inconsistent, why the updated scenario fixes the problem.]

Example:
Ontology context:
- Adult ⊆ Person; Person hasAge ≥ 0 and ≤ 110.
- Adult equivalent: Person and hasAge ≥ 18.
- Property isMarriedTo domain=Adult, range=Adult.

Story so far:
John is 15 years old.

Next scenario:
John is married to Amira.

Expected output:
Consistency: Inconsistent
Updated scenario: John is 23 years old and is married to Amira.
Explanation:
1. Ontology: "isMarriedTo domain=Adult" and "Adult ... hasAge ≥ 18". John is 15, so being married violates the domain constraint.
2. I changed John's age to 23 so he satisfies Adult and therefore the marriage relation is allowed. This is a minimal, natural fix preserving intended meaning.

Now analyze using the provided context below.

{context}

Next scenario:
{question}
""")

# %%
from langchain_core.prompts import PromptTemplate

fix_story_prompt = PromptTemplate.from_template("""
You are a reasoning assistant tasked with fixing inconsistencies in a story.

You are given:

The original story:
{original_story}
                                           
The original inconsistent scenarios/facts taken from the original story
{scenarios}

A list of updated, consistent scenarios/facts:
{updated_scenarios}

Your task is to rewrite the new updated scenarios into the original story. Make minimal changes to the original story; preserve the writing style, narrative flow, and character details as much as possible. 

Return only the fixed story.
""")

# %%
def fix_story(llm, story, scenarios, updated_scenarios):
    fixed_story = llm.invoke(fix_story_prompt.format(
    original_story=story,
    scenarios=scenarios,
    updated_scenarios="\n".join(updated_scenarios)
))
    return fixed_story.content

# %%
from typing import List, TypedDict, Optional, Dict, Any
from langgraph.graph import StateGraph, START, END
from owlready2 import get_ontology
from langchain_core.prompts import PromptTemplate
from langchain_ollama import ChatOllama

class StoryState(TypedDict, total=False):
    story: str
    ontology: Any
    scenarios: List[str]
    updated_scenarios: List[str]
    results: Any
    fixed_story: str
    llm: Any
    vector_store: Any

#Turns ontology into natural language docs for RAG
def vector_store_node(state: StoryState) -> Any:
    onto = state.get("ontology")
    vector_store = state.get("vector_store")
    vector_store = ontology_to_vector_store(onto, llm, vector_store)
    return {"vector_store": vector_store}

#Create scenarions based on story
def split_scenarios_node(state: StoryState) -> Dict[str, Any]:
    story = state.get("story", "")
    scenarios = scenario_splitter_llm(story, llm)
    return {"scenarios": scenarios}

#Fixes the scenarios incrementally
def check_consistency_node(state: StoryState) -> Dict[str, Any]:
    
    scenarios = state.get("scenarios")
    vector_store = state.get("vector_store")
    llm = state.get("llm",)
    updated_scenarios, results = fix_scenarios_incrementally(scenarios, vector_store, llm, scenario_fixing_prompt, k=5)
    return {"updated_scenarios" : updated_scenarios, "results": results}

#Fixes the story
def fix_story_node(state: StoryState) -> Dict[str, Any]:
    story = state.get("story", "")
    #results = state.get("results", [])
    scenarios = state.get("scenarios")
    updated_scenarios = state.get("updated_scenarios")
    fixed_story = fix_story(llm, story, scenarios, updated_scenarios)

    return { "fixed_story": fixed_story}

builder = StateGraph(StoryState)
builder.add_node("vector_store", vector_store_node)
builder.add_node("split_scenarios", split_scenarios_node)
builder.add_node("check_consistency", check_consistency_node)
builder.add_node("fix_story", fix_story_node)

builder.add_edge(START, "split_scenarios")
builder.add_edge(START, "vector_store")
builder.add_edge("vector_store", "check_consistency")
builder.add_edge("split_scenarios", "check_consistency")
builder.add_edge("check_consistency", "fix_story")
builder.add_edge("fix_story", END)

graph = builder.compile()

onto = get_ontology("./Ontology_Assignment.rdf").load()

from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")

from langchain_core.vectorstores import InMemoryVectorStore
vector_store = InMemoryVectorStore(embeddings)

#Story 1
#story = """John is 15 years old and is on vacation with his wife Amira in Italy. Their daughter Anna can’t wait to visit the Eiffel Tower, but first they will go out to eat. John suggests they eat pizzas since Italy is famous for them, they will eat at restaurant Riccolo located in Florence.
#Since Anna has a vitamin C deficiency she will order a pizza that contains lots of vitamin C, so she will get the pizza Bianca because that doesn't contain tomato's so this gives her more vitamin C than a pizza that does contain tomato's. John will get the classic Margherita pizza and Amira orders a pepperoni pizza.
#They sit by the window of the small restaurant; the air filled with the smell of garlic and baking dough. Anna swings her legs impatiently under the table, still talking about the Eiffel Tower, while Amira flips through a guidebook about Florence.
#15 minutes later the farmer named Leo from the restaurant brings their pizzas and they eat, and Anna says to John how cool it is that the waiter is from France."""

#Story 2
story = "Jack and his family are celebrating his birthday, Jack just turned 235 years old. Jack loves talking about himself and everything he has done in his life, many people would consider Jack a reserved person. This year, Jack’s family decided to visit the beautiful city of Quito, famous for its landmark La Virgen del Panecillo, which overlooks the city from a tall hill. Since the city doesn’t have mountainous terrain and is easy to walk through, Jack enjoys strolling through the streets without any trouble. It’s quite convenient, because Jack can’t walk very far due to his asthma. Luckily, Jack brought his medication, so whenever he’s out of breath, he can simply take his antihistamine pills."

#Story 3
#story = """Emily and her son Michael decided to adopt a cat from the local shelter in Denver, a walkable city surrounded by tall mountains. The city’s most famous landmark, the Red Rocks Amphitheatre, could be seen from their apartment window. Michael was thrilled to finally have a pet to take on walks through the flat city streets. The shelter worker handed them a small brown dog named Whiskers, explaining that he meows loudly when he wants food.
#Later that afternoon, Michael went to his scheduled health check-up for obesity, which the doctor said was likely caused by living in Denver. After the appointment, Michael decided to walk Whiskers around the flat, car-free neighborhood for some exercise. Denver has a large population, which makes it one of the largest cities in the USA. Michael finds Denver the quietest city he has ever been to.
#"""
#Story 4
#story = "Jason loves to work outside on the Farm, which is why he became a surgeon. He and his family live just outside of Barcelona in France where he grows apples. He is a very young father, with his daughter Amelie only being 4 years younger than him. When they visit the city Amelie gets very excited for all the vegan food, such as Chicken Tikka Masala, since she is vegetarian by choice but also lactose intolerant. Whenever they visit, they take their pet alligator Sally since she loves to meet other pets and is very social."

#Story 5
#story = """Lara traveled to Rome with her friend Amira to enjoy Italian cuisine, they were excited to try everything. However, it wasn’t easy since Lara was vegetarian, and her best friend was gluten-free. They finally both enjoyed the Pizza and Pasta. They also explored the beautiful city, walking everywhere they could. Lara had to use her EpiPen daily since she was highly allergic to animal hair and in many places they encountered street animals, such as cats and dogs.
#Lara loved the smell of baked bread from every corner, even though her friend couldn’t try any. When Lara returned home, she wanted to make food that everyone could enjoy, so she opened a small bakery and decided it would be completely gluten-free. Her favourite creation was bread made from rye.
#"""

llm = ChatOllama(
    #model="phi3:mini",
    model = "llama3.1"
)

initial_state: StoryState = {
    "story": story,
    "ontology": onto,
    "llm": llm,
    "vector_store": vector_store
}
from IPython.display import Image, display
final_state = graph.invoke(initial_state)
#display(Image(graph.get_graph(xray=True).draw_mermaid_png()))
# Out:
# Animals is a subclass of Thing.
# The class Food is defined as follows:
#
# * It is a subclass of Thing.
# The CookingStyles class is a subclass of the class called Thing.
# The class Place is defined as a subclass of the class Thing.
# The class NoiseLevel is a subclass of Thing.
# The class CharacterTrait is defined as a subclass of Thing.
# Behaviour is a subclass of Thing.
# Health Condition is a subclass of Health.
# The class Nutrient is a subclass of Food.
# The class City is defined as:
# * A type of Place
# * A location that exists within some Country.
# The class Health is a subclass of Thing.
# FoodAllergies is a class that:
#
# * Is a type of Allergy
# * Often comes with a Rash as a symptom
# * Often comes with a Swollen Tongue as a symptom
# * Requires treatment with EPIpen medication.
# The class AnimalHairAllergies is defined as follows:
#
# It inherits properties from:
# - AnimalAllergies
# - comesWithSymptom with unknown restriction Itching
# - comesWithSymptom with unknown restriction Rash
# - comesWithSymptom with unknown restriction RunnyNose
# - comesWithSymptom with unknown restriction Sneezing
# - comesWithSymptom with unknown restriction SwollenEyes
# Mammals is a subclass of Animals.
# The class Event is a subclass of Thing.
# The class Symptoms is a subclass of Thing.
# Occupation is a class that:
#
# Is a subclass of Thing, which means it's a type of thing in general.
# Is a subclass of requiresEducationalLevel, with an unknown restriction that every instance of Occupation must have at least one EducationLevel.
# The class Resource is a subclass of Product.
# The Adult class is defined as follows:
#
# * It is a subclass of Thing.
# * It is equivalent to both Person and hasAge, where hasAge must be restricted by at least 18 years (of type int).
# A person is a type of thing.
# A person must have at least one parent.
# The age of a person can be at most 110 years old.
# Landmark is a class that inherits from two parent classes:
# - Place
# - Located In, with the following restriction:
# Located in a city.
# The class Macro is a subclass of Nutrient.
# The Medication class is a subclass of the Thing class.
# Domesticated Animals is a class defined as follows:
# - It is a type of Animal.
# - It is exactly equivalent to Animals and having an owner, specifically with no restriction on who that owner must be. The property of having an owner is such that there exists at least one Person who owns the domesticated animal.
# The class Terrain is a subclass of Place.
# The Product class is a subclass of Thing.
# The class Elder is defined as follows:
# It is a subclass of Thing.
# It is equivalent to Person and must have an age that is at least 67 years old.
# EducationLevel is a subclass of Thing.
# The class Tool is a subclass of Product.
# The Workplace class is a subclass of Place.
# The Alligator class is a subclass of both WildAnimals and Reptiles.
# The class WildAnimals is defined as follows:
#
# It is a subclass of Animals.
# It is equivalent to two conditions:
# 1. Animals
# 2. Not having an owner with an unknown restriction that there exists at least one Person who has this animal as their owner.
# Reptiles is a subclass of Animals.
# The class AnimalSounds is a subclass of Thing.
# The class Bread is defined as follows:
# - It is a type of GlutenFood.
# - It can be cooked in some way by an OvenBake method.
# GlutenFood is defined as follows:
#
# It is a type of food that is based on something other than an animal.
# It can be either:
#   A food that does not contain wheat
# Or: It contains wheat or has some ingredient that is wheat.
# The class 'Bush' is a subclass of 'Forest'.
# The class Forest is defined as follows:
#
# * It is a subclass of NaturalResource.
# * It is a subclass of Place.
# * Its instances have noise levels that are always Quiet.
# ButterChicken is a class that inherits from two other classes:
# RiceDish
# hasIngredient with the value of ChickenFood, where the type of restriction is unknown.
# RiceDish is a class that:
# - Is a type of Dish
# - Can be cooked by boiling, where no further restrictions apply.
# - Can be cooked by oven baking, where no further restrictions apply.
# - Is equivalent to a Dish and has an ingredient called Rice.
# The class Cat is defined as follows:
#
# * It is a type of Domesticated Animal.
# * It is a type of Mammal.
# * It makes sound, specifically meowing, with an unknown restriction.
# Cheese is a type of thing that can be classified in several ways:
#
# It is a type of lactose.
# It is something that can be cooked by being melted, specifically.
# It is something that can be cooked by being left raw, specifically.
# It contains milk as an ingredient.
# The class Lactose is defined as a subclass of NotAnimalBased.
# The class Chicken is a subclass of Birds.
# The class Birds is a subclass of Animals.
# ChickenTikkaMasala is a type of dish that consists of rice, and it contains ChickenFood as an ingredient.
# The Cow class is a subclass of both Wild Animals and Mammals.
# The class Dog is defined as follows:
# - It is a type of Domesticated Animals.
# - It is a type of Mammals.
# - It makes sound, specifically it always produces the sound Woof.
# The class Eagle is defined as a subclass of Birds.
# The class Parrot is a subclass of Birds.
# EatingDisorder is a subclass of Disorder.
# The class "Disorder" is a subclass of "Health".
# The Egg class has two parent classes:
# - It is an instance of NotAnimalBased.
# - It is an instance of canBeTakenFrom with the restriction that it must be taken from something that has at least one Birds.
# The class NotAnimalBased is defined as a subclass of Ingredient.
# FishNonFood is a subclass of Fish.
# The class Fish is a subclass of both Animals and Material Resource.
# NaturalResource is a subclass of Resource.
# The Horse class is a subclass of Mammals.
# The class Lake is a subclass of Water.
# The Water class is a subclass of both Natural Resource and Place.
# A city is considered large if it has a noise level that is noisy and its population exceeds at least 500,000 people.
#
# It is also equivalent to be classified as both a city and having a population above or equal to 500,000.
# The class SmallCity is a subclass of City.
# It has the same meaning as City and has a population with at least one value that is less than 500,000.
# The class NonVegan is defined as a subclass of Dish, and it is equivalent to two other classes: it represents everything that is classified as a Dish and not as a VeganDish.
# A VeganDish is a type of VegetarianDish.
# It is equivalent to a VegetarianDish, except for instances that have an ingredient taken from Animals, which are not allowed.
# The class Dish is a subclass of Food.
# Paella is a type of RiceDish.
#
# It must have Shrimp as one of its ingredients.
# The class Shrimp is defined as a subclass of FishFood.
# Pasta is a type of food that contains gluten.
#
# Pasta can be cooked in certain ways, but it specifically can be boiled.
# PastaBolognese is a type of pasta dish that:
# - Must be a type of pasta in general
# - Must contain beef as an ingredient
# - Must contain tomato as an ingredient
# A pasta dish is a type of dish.
# It can be cooked by boiling and pan-frying.
# It is equivalent to a general dish and must contain pasta as an ingredient.
# The class PastaCarbonara is defined as follows:
#
# It is a type of pasta dish.
# It must contain chicken egg.
# It must contain pork.
# A pizza is a type of dish.
#
# It can be cooked in an oven.
#
# It is equivalent to other dishes and has ingredients that include pizza dough.
# The class PizzaDough is defined as follows:
#
# * It is a subclass of GlutenFood.
# * It is also a subclass of canBeCookedBy, but with an unknown restriction that it must be cooked by OvenBake.
# The class PizzaBianca is a subclass of Pizza.
# The class Plant is a subclass of Forest.
# Rice is a class that has three defining characteristics:
#
# * It is not based on animal products.
# * It can be found in locations where plants are available.
# * It can be cooked by boiling.
# The class Salmon is defined as being a subclass of FishFood.
# FishFood is a subclass of:
# - AnimalBased
# - Fish
# - Anything that is available at water, where the relationship between a thing and water is unknown.
# The class Sea is defined as a subclass of Water.
# The class Shark is a subclass of FishNonFood.
# The class Snake is a subclass of Reptiles.
# The Turtle class is a subclass of Reptiles.
# The class Tree is a subclass of Forest.
# The Underground class is a subclass of Place.
# A VegetarianDish is:
# - A type of Dish
# - Equivalent to another kind of dish that can have an ingredient, but only if it's not based on animal products.
# The class Adoption is a subclass of Animal Event.
# The class AnimalEvent is defined as follows:
#
# * It is a subclass of Event, which means it inherits all the properties and characteristics of an event.
# * It also has the property that at least one participant is an instance of Animals, but the specific relationship between AnimalEvent and hasParticipant is restricted with unknown criteria.
# The class AirborneAllergies has the following properties:
#
# * It is a type of Allergy.
# * It can be characterized by the symptom RunnyNose.
# * It can be characterized by the symptom Sneezing.
# * It can be characterized by the symptom SwollenEyes.
# * A treatment for it may include taking EyeDrops.
# Allergies is a class that inherits from Disorder.
#
# It is also a subclass of hasMedication, with the restriction that the medication must be an Antihistamine.
# AnimalAllergies is a subclass of Allergies.
# The class AnimalBased is a subclass of Ingredient.
# The class Ingredient is a subclass of Food.
# InsectAllergy is a type of allergy that is defined by several characteristics:
#
# It is a type of AnimalAllergies.
# It comes with Itching as a symptom, where the presence or absence of this symptom cannot be determined.
# The class Artwork is a subclass of Documents.
# The class "Documents" is a subclass of "Product".
# The class "Bakery" is a subclass of "Workplace".
# The class Birth is a subclass of LifeEvent.
# LifeEvent is a class that inherits from two other classes:
# - It is an Event
# - It is a hasParticipant with at least one Person.
# Cancer is a type of Disease.
# It often comes with Fatigue.
# It often comes with Weight Loss.
# It can be treated with Chemo.
# It can be treated with Radiation.
# The class "Disease" is defined as being a subclass of "Health".
# The Checkup class is a subclass of HealthEvent.
# The HealthEvent class is defined as:
#
# * A subclass of Event
# * A subclass of hasParticipant, with a restriction that at least one participant must be of type Person. The nature of this restriction (whether it's mandatory or optional) is unknown.
# The class Child is defined as follows:
#
# * It is a subclass of Thing.
# * It is equivalent to both Person and has an age that is unknown, but some instances of ConstrainedDatatype (int) with a maximum exclusive value of 18.
# The Country class is a subclass of the Place class.
# Coal is a subclass of EnergyResource.
# The class EnergyResource is a subclass of Resource.
# The class ConstructionTool is a subclass of the class Tool.
# The class CreativeWorker is a subclass of Occupation.
# Death is a subclass of LifeEvent.
# A DrivableCity is:
#
# * A type of thing
# * Something that can affect someone's health condition in relation to obesity
# * Equivalent to a city and something with a car-to-population ratio where at least 500 people live per car.
# The class EducationalEvent is defined as follows:
#
# It is a subclass of Event.
# It must have at least one participant, which is an instance of Person.
# The class Electricity is a subclass of EnergyResource.
# The class Enrollment is a subclass of Educational Event.
# The class Exam is a subclass of EducationalEvent.
# A farm is a type of workplace, and it is typically located on farmland.
# Farmland is a subclass of both Natural Resource and Place.
# The class MaterialResource is defined as being a subclass of Resource.
# FlatTerrain is a subclass of Terrain.
# MountainousTerrain is defined as:
# - A type of Terrain
# - A type of area with an unknown level of noise, specifically one that is Quiet.
# The class Flour is a subclass of MaterialResource.
# The class Fruits has two subclass relationships:
#
# * It is a subclass of NotAnimalBased.
# * It is a subclass of canBeCookedBy, with a restriction that its value must be Ontology_Assignment.Raw.
# The Gas class is a subclass of EnergyResource.
# The class GastronomyWorker is a subclass of ServiceWorker.
# The class Service Worker is a subclass of Occupation.
# The class Gluten is a subclass of Nutrient.
# The class Wheat is defined as follows:
#
# * A type of GlutenFood
# * A type of MaterialResource
# * A resource that can be found at some location, specifically on untitled-ontology-8.Farmland.
# The Graduation class is a subclass of EducationalEvent.
# The HealthWorker class is defined as being a subclass of Occupation.
# The Hospital class is defined as a subclass of Workplace.
# Illness is a subclass of HealthEvent.
# Inhalation is a subclass of Medication.
# The class Injection is a subclass of Medication.
# Job End is a subclass of Work Event.
# A WorkEvent is an Event that has at least one Participant, which must be a Person.
# A WorkEvent also takes place at least one Workplace.
# The class JobStart is a subclass of WorkEvent.
# The class KitchenTool is a subclass of Tool.
# A KnowledgeWorker is a type of occupation that requires a bachelor's educational level.
# Manual Worker is a subclass of Occupation.
# The class Marriage is a subclass of LifeEvent.
# MeatFood is a subclass of AnimalBased.
# MedicalReport is a subclass of Documents.
# The class MedicalTool is a subclass of Tool.
# MedicanAllergies is a class that meets certain conditions.
#
# It must be an Allergy.
# It comes with symptoms, specifically:
# - A rash
# - Swollen eyes
# - A swollen tongue
# The class Micro is a subclass of Nutrient.
# The class Mineral is defined as being a subclass of Micro.
# The class Minerals is a subclass of Natural Resource.
# A NonVegetarianDish is:
#   A type of dish
#   Equivalent to a regular dish that contains an ingredient derived from animals.
# NutAllergies is a class that has two properties:
#
# It inherits from FoodAllergies, meaning it is a type of food allergy.
# It also inherits from cannotEat, but there are some restrictions on this relationship. Specifically, someone with NutAllergies cannot eat Nuts.
# The class Nuts has three subclasses:
# - NotAnimalBased
# - Things that can be cooked by deep frying, with unknown restriction
# - Things that can be cooked by leaving uncooked (raw), with unknown restriction
# The class Office is a subclass of Workplace.
# OfficeTool is a subclass of Tool.
# OnSkin is a subclass of Medication.
# Pain is a subclass of Symptoms.
# The class "Pills" is a subclass of "Medication".
# The class PizzaMargherita is defined as follows:
# It is a subclass of Pizza.
# It is a subclass of hasIngredient, with the restriction that it must have Tomato as one of its values.
# The class PizzaPollo is defined as follows:
# It is a subclass of Pizza.
# It is also a subclass of hasIngredient, where the ingredient must be ChickenFood.
# The class Promotion is a subclass of WorkEvent.
# ProteinDeficiency is a class that inherits from two classes:
# HealthCondition
# needsToEat, with the following condition: it must have some instance of Macro in its hasMacro attribute that contains Protein.
# VitaminDeficiency is a class that inherits from two other classes:
#
# * It is a type of HealthCondition.
# * It involves needing to eat something related to Vitamin, but the specific nature of this requirement is unknown.
# The class Restaurant is a subclass of Workplace.
# The class ScientificPublication is a subclass of Documents.
# The class SkinAllergies is a subclass of:
# * Allergies
# * Comes with symptom, where the symptom is unknown but belongs to the set of SkinSymptoms.
# * Comes with symptom, where the specific symptom is Swollen Eyes.
# Skin Symptoms is a subclass of Symptoms.
# SolarEnergy is a subclass of EnergyResource.
# StomacheSymptoms is a subclass of Symptoms.
# The Studio class is a subclass of the Workplace class.
# The class Sun is a subclass of Natural Resource.
# The class Surgery is a subclass of HealthEvent.
# The class Teacher is a subclass of KnowledgeWorker.
# A TechnicalWorker is an Occupation that requires a ConstructionTool.
# The class Training is a subclass of AnimalEvent.
# The class "University" is defined as being a subclass of "Workplace".
# Vegetables is a class that has several properties:
#
# * It is a subclass of NotAnimalBased, meaning it does not come from animal sources.
# * It can be cooked in four ways:
#   - Boiling
#   - Deep frying
#   - Pan frying
#   - Eating raw.
# The class "Veterinary Visit" is a subclass of "Animal Event".
# The Vitamin class is a subclass of the Micro class.
# The class WalkableCity is defined as follows:
# It is a subclass of City.
# It is equivalent to City and has terrain type which is some FlatTerrain.
# Water is a subclass of MaterialResource.
# The class "Wood" is a subclass of "MaterialResource".
# The property MakesSound has a domain of Animals.
# The property canBeCookedBy has:
#
# Domain: Food
# Range: CookingStyles
# The property "canBeTakenFrom" has the following characteristics:
#
# It applies only to things that are Food (its domain).
# Its values must be Animals.
# This relationship can be followed through multiple steps, meaning if A can be taken from B and B can be taken from C, then A can also be taken from C.
# The property "hasAJobAt" is associated with an employer and a job title, indicating that an individual occupies a specific position in the workplace.
#
# Note: This conversion was based on the assumption that the hasAJobAt property relates to employment information. If this interpretation is incorrect, please provide more context or clarify the purpose of the hasAJobAt property.
# The property "hasNoiseLevel" is defined with the following characteristics:
#
# * It applies only to instances of "Place".
# * Its value must be an instance of "NoiseLevel".
# The property called impliesBehaviour has a domain of CharacterTrait and a range of Behaviour.
# The property `isAvailableAt` has a domain of `Food` and a range of `Place`.
# The property needsToEat applies to health conditions and relates them to specific nutrients that are required.
# The "affectsHealthCondition" property has two key characteristics:
#
# * It applies to cities.
# * Its values relate to health conditions.
# The property "hasHealthCondition" indicates that a person or entity possesses a specific health condition.
# The property "canBeSymptomOf" relates one thing to another that it could be a symptom of.
#
# It indicates that the first thing has the potential to manifest as, or be indicative of, the second thing.
# The property "comesWithSymptom" has two characteristics:
#
# * Its domain is "Health", meaning it can only be applied to something related to health.
# * Its range is "Symptoms", meaning its value must be a symptom.
# The property "cannotEat" has two characteristics.
#
# Its domain is restricted to instances of "FoodAllergies".
#
# Its range is restricted to instances of "Food".
# The property comesWithHealthCondition has the following definition:
#
# It associates an entity with one or more health conditions that it comes with.
# The property "cannotPet" has two specifications:
#
# * It applies only to things that are related to animal hair allergies, meaning it describes characteristics of these items.
# * Its values must be mammals.
# The property causesEvent relates events and has the following characteristics:
#
# * It can only be used with events (its domain).
# * Its value must also be an event (its range).
# * An individual cannot cause itself as an event.
# The property 'consumesResource' has the following characteristics:
#
# Domain: This property applies to concepts related to an individual's occupation.
# Range: The value of this property can be any concept that represents a resource.
# The eatable property applies to entities that are animals and has values that are food items.
# A city is famous for food.
# The type of thing that can be famous for food is food.
# No city is famous for food in relation to itself.
# The followsEvent property has the following characteristics:
#
# - Its domain is Event, meaning it can only be applied to an event.
# - Its range is also Event, indicating that it relates one event to another.
# - It is asymmetric, which means if event A follows event B, then event B does not follow event A.
# - The property is irreflexive, signifying that no single event can follow itself.
# The property hasChild is defined as follows:
#
# * It can only be applied to an Adult.
# * The result of applying this property must be a Person.
# * An individual cannot have itself as a child.
# The hasRelation property can be related to one or more entities through either a role or an instance of a relation type. The entity being described may have multiple relations with different roles or relation types.
# The hasParent property applies to individuals who are people and relates them to adults, but no person can be their own parent.
# The property "hasDiet" applies only to individuals of type "Person". Its value can be any "Food".
# The property "hasFavoriteFood" is defined as follows:
# - It applies to entities of type "Person".
# - Its values must be instances of "Food".
# - There can only be one value assigned to this property for each entity.
# The property hasFoodNutrient has the following characteristics:
#
# Domain: The property can be applied to food.
# Range: The property can only have food as its value.
# Transitive: If one food has another food that in turn has a third food, then the first food is considered to have the third food.
# The property "hasHealth" applies to individuals of type "Person". It describes a relationship with a concept called "Health".
# The property hasIngredient applies to food items and its values are also food items. It can be used to connect food items in a chain of relationships where one food item contains another.
# The property "isIngredientOf" has the following characteristics:
#
# * It can only be used with something that is a type of food (domain: Food).
# * The result of using this property should also be a type of food (range: Food).
# * If A is an ingredient of B, and B is an ingredient of C, then A is an ingredient of C.
# The property "hasJob" applies to people and its values are occupations. Each person can have at most one job.
# The property "hasLandmark" is defined with a specific domain and range.
#
# It has a domain of: City
# It has a range of: Landmark
# The property "hasMacro" is restricted in its application and meaning as follows:
#
# It can only be used with things that are foods.
# Its value must always be a macro.
# The property "hasMedication" is defined with two characteristics:
#
# * Its domain is "Health", meaning it can only be used in the context of health-related things.
# * Its range is "Medication", meaning it is used to indicate or describe medication.
# The property "helpsHealthCondition" indicates that its associated value has a beneficial effect on one or more health conditions.
# The hasMicro property applies to foods (its domain) and its value can only be another food (its range). The property is also transitive, meaning that if one food has micro and another has the first food as micro, then the second food also has micro.
# The property "hasOccupation" applies to individuals who are people and describes their occupation.
# The property hasOwner is defined with two constraints:
#
# Domain: The hasOwner property can only be used for domesticated animals.
# Range: The value of the hasOwner property must be a person.
# This property is functional, which means it can have at most one value.
# The hasParticipant property applies to Events and indicates that they have participants which can be either Animals or People.
# The hasSibling property applies only to individuals who are Persons. It relates one Person to another Person, indicating that they are siblings. A person can be related to another person through this property in both directions, meaning if person A is a sibling of person B, then person B is also a sibling of person A. Additionally, no individual can be related to themselves as a sibling.
# The property hasSymptoms is defined with two components:
#
# Domain: The entity that this property can be applied to is a Person.
# Range: The kind of thing that this property describes is Symptoms.
# The property `hasTerrainType` has the following definition:
#
# * It can only be applied to things that are cities.
# * Its values must be types of terrain.
# * A city can have at most one type of terrain.
# The property "hasTrait" applies to individuals of the class "Person". Its values must be instances of the class "CharacterTrait".
# The property "involves" has a domain of "Event" and a range of "Product".
# A person isfriendof another person if and only if they are friends.
#
# This relationship applies to two people, both of whom must be individuals.
#
# The relationship between two people is symmetrical: if one person is friendsof the other, then the reverse also holds.
#
# An individual cannot be their own friend.
# The property "isMarriedTo" applies to individuals who are either adults or elders.
#
# It relates individuals who are also either adults or elders.
#
# At most one individual can be related as married to another by this property.
#
# If A is related as married to B, then B is also related as married to A.
#
# A cannot be related as married to itself.
# The property "isPredatorOf" applies to:
#
# Animals that can be predators
# Only to other Animals, as prey.
#
# This relationship cannot exist between an Animal and itself.
# It also cannot exist if A is predator of B and B is already predator of A.
# The property `isPreyOf` has the following characteristics:
#
# * It applies to individuals that are Animals.
# * Its value must be another Animal.
# * The relationship is one-way, meaning an individual cannot both prey on and be prey of another individual at the same time.
# * An individual cannot have a self-referential relationship with itself through this property.
# The property "isSignatureFoodOf" has three defining characteristics:
#
# * The type of thing that it describes must be a "Food".
# * The location where it is typically found is a "Place".
# * Each place can only be associated with one food, meaning that if two foods have the same signature place, they are likely to be the same food.
# The property 'livesIn' applies to entities that are Animals and its values can be Places.
# The property locatedIn has the following characteristics:
#
# * It applies only to things that are places.
# * Its values must also be places.
# * The relation between two places holds if it holds between one of them and another place.
# The property "produces" is defined by the following criteria:
#
# * It applies to things that are occupations.
# * Its value must be something that is a product.
# The property 'requiresEducationalLevel' has a range of 'EducationLevel'.
# The `requiresResource` property has the following characteristics:
#
# * It applies only to tools.
# * Its value must be a resource.
# The property "requiresTool" has two key characteristics:
#
# Domain: This property can be used to describe occupations.
# Range: The result of using this property should be a tool.
# The property "served with" has two requirements:
#
# * It can only be used to relate one food item to another, where the first item is the main course.
# * The second item it relates must also be a type of food.
#
# This relationship can go in either direction.
# The property "should avoid food" applies to individuals and has values that are types of food.
# The property "similarTasteTo" is defined with the following characteristics:
#
# Domain: The property can only be applied to instances of "Food".
# Range: The property's value must also be an instance of "Food".
# This relationship is symmetric, meaning that if one food has a similar taste to another, the second food also has a similar taste to the first.
# The property "similarTo" has two properties associated with it:
# Domain: It applies to occupations.
# Range: Its values are also occupations.
# The property takesPlaceAt has the following characteristics:
#
# * It applies only to events (its domain).
# * Its value must be a place (its range).
# The property 'works at' applies to occupations and has workplaces as its possible results.
# The property carRatio has the following characteristics:
#
# Domain: It applies to cities.
# Range: Its value must be an integer.
# The property hadBodyHeight has the following definition:
#
# It applies only to entities of type Person.
# Its value must be an integer.
# The property hasIndividualCharacteristic is an attribute that can be applied to individuals. It describes a characteristic or feature of that individual.
#
# A characteristic is defined as an instance-level classification, which means it pertains specifically to one particular instance rather than being general and universal.
# The property "averageIncome" has two main characteristics:
#
# It relates to occupations, meaning it describes something about them.
# Its value can only be a floating-point number (a decimal value).
# The property named averageLifespan applies to entities that are classified as Animals and has a value of a whole number.
# The property "averageWeight" has two main characteristics:
#
# 1. Its domain, which refers to the type of entity that can have this property, is "Animals".
# 2. Its range, which specifies the possible values or types of data that can be associated with this property, is a floating-point number.
# The property "builtInYear" has two parts:
#
# Domain: The property "builtInYear" can only be used with things that are Landmarks.
# Range: The value of the property "builtInYear" must be an integer.
# The hasTemporalCharacteristic property is defined.
#
# This property is a characteristic that can be attributed to something over time.
# The hasAge property applies to individuals of type Animal and Person.
# It can only have an integer value as its result.
# There can be at most one such value associated with each individual.
# The hasBuildingHeight property has the following characteristics:
#
# Domain: It applies only to Landmarks.
# Range: Its value must be an integer.
# It can have at most one value.
# The property hasDate is defined with two characteristics:
#
# It applies only to instances of Event (Domain: Event).
# Its value must be a specific type of date and time, known as a datetime object (Range: <class 'datetime.datetime'>).
# The property "hasDuration" is defined with the following characteristics:
#
# Domain: The concept that this property can be applied to is an "Event".
# Range: The value of this property must be a string.
# The property hasGender is defined as follows:
# It applies to persons.
# Its values are strings.
# Each person can have at most one value for this property.
# The property hasPopulation has the following characteristics:
#
# Domain: The concept of this property applies specifically to City.
# Range: This property's values are integers.
# This property is functional, meaning that each instance of it can have at most one value.
# The property hasWeight has the following characteristics:
#
# - It applies to entities that are either animals or people.
# - Its value must be an integer.
# The property "isDomesticated" has a domain of "Animals". Its range is a boolean value.
# The maximum daily hours of work for an occupation must be an integer value.
# The property `minRequiredAge` has two defining features:
#
# It applies to occupations.
# Its value must be an integer.
# The property "requiresPhysicalLabour" has the following characteristics:
#
# * It applies to something related to an occupation (its domain is "Occupation").
# * Its value can be either true or false (it has a range of boolean values).
# OvenBake belongs to the class(es) CookingStyles.
# ChickenFood belongs to classes: MeatFood.
# It has the property Macro with value: Protein.
# Meow belongs to the classes Animal Sounds.
# The instance Melt belongs to one or more classes of CookingStyles.
# The concept of Raw belongs to a category known as CookingStyles.
# Milk belongs to the class Lactose and can be cooked by Raw methods.
# Woof belongs to the class AnimalSounds.
# Quiet belongs to the classes NoiseLevel.
# Noisy belongs to the classes NoiseLevel.
# The instance Boil belongs to the classes CookingStyles.
# Beef belongs to the classes MeatFood. It contains macro (large-scale) amounts of protein.
# The instance Tomato belongs to the class Vegetables and has the property VitaminC, denoted as hasMicro.
# ChickenEgg belongs to the class Egg and can be cooked by Boiling or Pan Frying.
# The instance Pork belongs to the classes: MeatFood.
# PanFry belongs to the category of CookingStyles.
# Runny nose is a symptom that can be caused by having flews.
# Sneezing belongs to the class of symptoms and can be a symptom of an outbreak of flies.
# Swollen eyes is an instance of symptoms and can be a symptom of dust mite allergy.
# The instance "EyeDrops" belongs to the classes "OnSkin".
# The antihistamine belongs to the class of pills.
# Itching belongs to classes including Skin Symptoms. Itching can be a symptom of Skin Cancer.
# The instance Rash belongs to the class (or classes) of Skin Symptoms.
# Rash can be a symptom of both Breast Cancer and Skin Cancer.
# Fatigue belongs to the category of symptoms. It can be a symptom of asthma and diabetes.
# WeightLoss belongs to the classes of Symptoms.
# It can be a symptom of Anorexia.
# The instance Chemo belongs to one or more classes, specifically Injection.
# Radiation belongs to the classes OnSkin.
# The concept of Obesity belongs to the category of Eating Disorder and is characterized by Weight Gain.
# The instance "Swollen Tongue" belongs to one class: Symptoms.
# EPIpen belongs to the classes of injection.
# The concept of Bachelor belongs to the category of Education Level and requires an educational level of High school.
# The concept of DeepFry belongs to the category of CookingStyles.
# The instance "Protein" belongs to one or more classes known as "Macro".
# The concept of Active belongs to a category called CharacterTrait and indicates that it implies behaviour associated with LovesExercise.
# The instance "LovesExercise" belongs to one or more classes named "Behaviour".
# Amelie is an instance of one or more classes, specifically a Child.
# Amelie's parent is Jason.
# Anorexia belongs to the class Eating Disorder and comes with the symptom of Weight Loss.
# Barcelona belongs to the class of City.
# The car-to-person ratio in Barcelona is approximately 500 per person.
# Barcelona is located within Spain.
# The population of Barcelona is 1,620,809 people.
# Spain belongs to the class of countries.
# The concept of Carbohydrate belongs to the category of Macros.
# The instance Champignon belongs to classes: Vegetable(s).
# The instance Denver belongs to one class, which is City.
# It also has several specific characteristics:
# - It has a car ratio of 1918.
# - It is located in USA.
# - Its population is approximately 730000.
# The instance "USA" belongs to the class of countries.
# Ecuador belongs to the class of countries.
# Emily is an adult who has a child named Michael.
# Michael belongs to the classes Child.
# Michael's parent is Emily.
# The instance "Fat" belongs to one or more classes, specifically "Macro".
# The instance HatesMeetingPeople belongs to one or more classes named Behaviour.
# The instance "LikesMeetingPeople" belongs to the classes "Behaviour".
# The instance HatesTalking belongs to the class(es) Behaviour.
# Jason is an adult and is the parent of Amelie.
# LaVirgenDelPanecillo belongs to the class of Landmarks and meets the following criteria:
#
# It was built in 1975.
# Its height is 41 meters.
#
# It is located in Quito.
# Quito belongs to the class of cities and has the following characteristics:
#
# It has a car ratio of 234.
# It is located in Ecuador.
# Its population is approximately 2,342,000 people.
# Lara belongs to the class Thing.
# The instance LovesTraveling belongs to the class Behaviour.
# Weight Gain belongs to the class of symptoms and can be a symptom of obesity.
# Olive belongs to the classes of Fruits.
# The concept of Potato belongs to the category of Vegetables.
# The RedRocksAmphitheatre instance belongs to one or more classes known as Landmark.
# It was built in 1941.
# Its building height is 1970 meters.
# RedRocksAmphitheatre is located in Denver.
# The reserved trait belongs to the category of character traits and implies that someone with this trait would hate meeting people and hate talking.
# The concept of Social belongs to the category of CharacterTraits and implies that an entity with this characteristic typically enjoys meeting people.
# Riccolo belongs to the class of restaurants.
# Florance is defined as follows:
#
# * It belongs to the class City.
# * It has a landmark called DuomoDiFirenze.
# * Its location is Italy.
# * It has a population of 360,930.
# * The ratio of cars is 694.
# Sally belongs to the class of Alligator.
# Tofu belongs to the classes NotAnimalBased.
# AbdominalPain is an instance that belongs to the classes Pain.
# It can be a symptom of ColonCancer.
# The instance Actor belongs to one or more classes, which are specified as CreativeWorker.
# Adventurous belongs to the category of Character Traits and implies that someone with this trait loves traveling.
# Almond allergy is classified under nut allergies.
# Cannot eat almonds due to this condition.
# The instance Almonds belongs to the classes Nuts.
# Amira belongs to the class Adult and has the following characteristics:
#
# * She is married to John.
# * Her child is Anna.
# * She suffers from a gluten allergy, which is a health condition.
# * Amira's age is 32 years.
# Gluten allergy is a type of food allergy.
#
# It belongs to the category of food allergies.
# Anna belongs to the class of Children.
# Anna's age is 8 years old.
# Anna's parents are Amira and John.
# John belongs to the class Adult.
# He has a child named Anna.
# His age is 34 years.
# He is married to Amira.
# Anxiety belongs to the category of disorders and has the symptom of shortness of breath.
# ShortnessOfBreath is a symptom that belongs to the class of symptoms. It can be a symptom of anxiety, asthma, and lung cancer.
# The instance Apple belongs to the class(es) Fruits.
# Banana belongs to the class(es) Fruits.
# The instance Orange belongs to the classes Fruits.
# The artist is classified as a creative worker.
# Asthma is defined as follows:
# It belongs to the category of Health Conditions.
# It is associated with having Asthma Inhaler as its medication.
# It comes with symptoms including Fatigue, Shortness Of Breath, Chest Pain, and Coughing.
# A ChestPain instance belongs to the classes Pain. A ChestPain instance can be a symptom of Asthma, Breast Cancer, and Lung Cancer.
# Coughing belongs to classes of symptoms. It can be a symptom of asthma and it can be a symptom of flew.
# An inhaler for asthma is an instance of the concept:
#
# Inhalation, which is a type of medical treatment.
# It is used to help alleviate Asthma, a specific health condition.
# High school belongs to the category of education level.
# The instance Baker belongs to one or more classes, which are specified as ManualWorker.
# The ontology instance BeeAllergy belongs to the class(es) InsectAllergy.
# The instance named MusquitoAllergy belongs to the classes named InsectAllergy.
# Bloating belongs to one or more classes of symptoms that occur in the stomach.
#
# It can be a symptom of colon cancer.
# BlurredVision belongs to one or more classes labeled as Symptoms.
# It can be a symptom of Diabetes.
# Breast cancer has the following properties:
#
# - It belongs to the category of cancers.
# - It often comes with symptoms including rash and chest pain.
# Broccoli belongs to the class of Vegetables.
# The instance "Carpenter" belongs to the classes: "TechnicalWorker".
# Cat Allergy belongs to class Animal Hair Allergies.
# The class DogAllergy belongs to the class AnimalHairAllergies.
# ColonCancer is classified as a type of Cancer.
# It is characterized by several symptoms:
# AbdominalPain
# Bloating
# Constipation
# Diarrhea
# The instance Constipation belongs to the classes that are stomach symptoms and can be a symptom of colon cancer.
# Diarrhea is a type of stomach symptom and can be a symptom of colon cancer.
# The concept of Computer is classified under OfficeTool.
# The instance Printer belongs to one or more classes, which are specified as OfficeTool.
# The entity ConstructionWorker is an instance of one or more classes, specifically including the class ManualWorker.
# The instance Cook belongs to the class GastronomyWorker.
# Diabetes belongs to the class of diseases.
#
# It has medication: insulin.
#
# It comes with symptoms: fatigue, blurred vision, hunger, and thirst.
# The instance Flew belongs to one or more classes known as Disease and has associated symptoms of RunnyNose, Sneezing, Coughing, Fever, and Headache.
# Hunger belongs to one or more classes of symptoms.
# It can be a symptom of diabetes.
# Thirst is classified as a symptom.
# It can be a symptom of diabetes.
# A Doctor is a type of Health Worker that requires an educational level of Medical Doctor.
# A medical doctor is characterized by having an education level of:
# Bachelor's degree
# High school diploma
# Master's degree
# A Doctorate belongs to the class of Education Level and requires educational levels of Bachelor, High School, and Master.
# The class Master belongs to the class EducationLevel and has two required educational levels: Bachelor and High School.
# The instance Drill belongs to the class(es) ConstructionTool.
# The instance Hammer belongs to the class(es) ConstructionTool.
# The instance Driver belongs to one or more classes: ServiceWorker.
# The DuomoDiFirenze instance belongs to one class: Landmark.
# It was built in 1296 and its height is 115 units.
# It is located in Florance.
# DustMitesAllergy belongs to the classes of airborne allergies and includes the symptom swollen eyes.
# HayFever belongs to the classes AirborneAllergies.
# EggAllergy is an instance of one or more classes, specifically FoodAllergies.
# The Eiffel Tower belongs to the category of Landmarks and has the following characteristics:
#
# * It was built in the year 1887.
# * Its height is 330 meters.
#
# Additionally, it can be found in Paris.
# Paris is an instance of one or more classes, specifically City.
# It has one landmark, which is EiffelTower.
# Its location is France.
# It has a population of 2234105 people.
# The ratio of cars to something ( likely the population) is 207.
# An electrician belongs to a group of technical workers.
# The instance Engineer belongs to one or more classes, specifically: KnowledgeWorker.
# The Farmer instance belongs to the class ManualWorker.
# Fever belongs to one or more classes of symptoms. Fever can be a symptom of Flew.
# The instance Fisherman belongs to the class(es) ManualWorker.
# A headache belongs to the class of pain and can be a symptom of a fly bite.
# Italy belongs to the class of countries.
# France belongs to the class Country.
# Friendly belongs to the class CharacterTrait.
# The instance GoodHearted belongs to the class CharacterTrait.
# The instance Insulin belongs to classes Injection and helps to manage Diabetes.
# Knife belongs to classes: Kitchen Tool.
# The instance LactoseAllergy belongs to the classes FoodAllergies.
# Leo belongs to the class of Adults.
# He works as a Waiter at Riccolo.
# His age is 23 years old.
# The entity "Waiter" is an instance of one or more classes, specifically "GastronomyWorker".
# LungCancer has the following properties:
#
# It belongs to the class of diseases known as Cancer.
# It comes with two symptoms: ShortnessOfBreath and ChestPain.
# The concept of Mechanic belongs to one or more categories, specifically Technical Worker.
# The instance Miner belongs to one or more classes, specifically ManualWorker.
# The instance Mixer belongs to the classes KitchenTool.
# A musician belongs to a category of creative worker.
# The instance "Nurse" belongs to the classes specified by "HealthWorker".
# The instance "Oven" belongs to the classes "KitchenTool".
# Painkiller belongs to pills.
# PeanutAllergy belongs to the classes of NutAllergies and has the restriction that it cannot eat Peanuts.
# Peanuts belongs to class(es): Nuts.
# The Plaster belongs to the Medical Tool class.
# The instance Scalpel belongs to one or more classes: MedicalTool.
# A school teacher belongs to the class of teachers.
# A scientist belongs to the category of knowledge workers.
# Skin cancer belongs to the category of cancers and comes with symptoms of itching and rashes.
# The instance Syringe belongs to the class MedicalTool.
# VitaminC belongs to the class (or classes) of Vitamin.
# A UniversityTeacher is a type of Teacher.
# Vitamin C Deficiency is an instance that belongs to one or more classes: Vitamin Deficiency.
# A vocational qualification belongs to the category of education levels and requires a high school educational level.
# Walnut Allergy is an instance of allergy that belongs to the category of nut allergies.
# It is characterized by an inability to consume walnuts.
# The instance "Walnuts" belongs to the class "Nuts".
# The instance Writer belongs to classes: CreativeWorker.

# %%
#Print Created scenarios from Story
final_state["scenarios"]
# Out:
# ['Jack just turned 235 years old and is celebrating his birthday with his family.',
#  'Many people would describe Jack as a reserved person despite him loving to talk about himself.',
#  "Jack's family decided to visit the city of Quito for his birthday celebration.",
#  'The city of Quito has a landmark called La Virgen del Panecillo that overlooks the city from a tall hill.',
#  'Quito is known for being easy to walk through due to its lack of mountainous terrain.',
#  'Jack suffers from asthma, which makes it difficult for him to walk long distances.',
#  'Jack brought his medication (antihistamine pills) with him on the trip to manage his asthma symptoms.']

# %%
#Print Updated scenarios from Story
final_state["updated_scenarios"]
# Out:
# ['Jack just turned 67 years old and is celebrating his birthday with his family.',
#  'Many people would describe Jack as an adventurous person despite him being reserved and not necessarily loving to travel.',
#  "Jack's family decided to visit the city of Quito for his birthday celebration.",
#  'The city of Quito has a landmark called LaVirgenDelPanecillo that overlooks the city from a tall hill.',
#  'Quito is a WalkableCity due to its lack of mountainous terrain.',
#  "Jack's family decided to visit Quito by taking taxis or public transportation so that Jack can easily reach LaVirgenDelPanecillo without exerting himself too much.",
#  'Jack brought his EpiPen (an injection of antihistamines) with him on the trip to manage his asthma symptoms.']

# %%
#Print Final fixed Story
print(final_state["fixed_story"])
# Out:
# Here's the rewritten story with the inconsistent scenarios corrected:
#
# Jack and his family are celebrating his birthday, Jack just turned 67 years old. Jack loves talking about himself and everything he has done in his life, many people would consider Jack an adventurous person - although they might not think that at first glance, given how reserved he can be when he's meeting new people. This year, Jack’s family decided to visit the beautiful city of Quito, famous for its landmark La Virgen del Panecillo, which overlooks the city from a tall hill. Since the city is known as a walkable city due to its lack of mountainous terrain, Jack enjoys strolling through the streets without any trouble - although it’s not always possible, given his asthma can make walking long distances difficult. Luckily, Jack brought his EpiPen with him on the trip to manage his symptoms, so whenever he's out of breath, he can simply take a quick injection.
#
# Note: I've tried to preserve the original writing style and narrative flow as much as possible while making minimal changes to fix the inconsistencies.

# %%
#Print reasoning etc from fixing scenarios function (Check explantion & ontology used to figure out llm reasoning)
reasoning_data = final_state["results"]
reasoning_data
# Out:
# [{'step': 1,
#   'original': 'Jack just turned 235 years old and is celebrating his birthday with his family.',
#   'updated': 'Jack just turned 67 years old and is celebrating his birthday with his family.',
#   'consistency': 'Inconsistent',
#   'ontology_used': "Leo belongs to the class of Adults.\nHe works as a Waiter at Riccolo.\nHis age is 23 years old.\n\nThe class Elder is defined as follows:\nIt is a subclass of Thing.\nIt is equivalent to Person and must have an age that is at least 67 years old.\n\nJohn belongs to the class Adult.\nHe has a child named Anna.\nHis age is 34 years.\nHe is married to Amira.\n\nLifeEvent is a class that inherits from two other classes:\n- It is an Event\n- It is a hasParticipant with at least one Person.\n\nMichael belongs to the classes Child.\nMichael's parent is Emily.",
#   'llm_raw_output': 'Consistency: Inconsistent\n\nUpdated scenario: Jack just turned 67 years old and is celebrating his birthday with his family.\n\nExplanation:\n1. Ontology: "Elder equivalent ... must have an age that is at least 67 years old" and "John belongs to the class Adult with an age of 34, which does not make him an Elder." \n2. I changed Jack\'s age to 67 so he satisfies the definition of the Elder class.\n3. This fix preserves the intended meaning while making the scenario consistent with the ontology context.',
#   'explanation': '1. Ontology: "Elder equivalent ... must have an age that is at least 67 years old" and "John belongs to the class Adult with an age of 34, which does not make him an Elder." \n2. I changed Jack\'s age to 67 so he satisfies the definition of the Elder class.\n3. This fix preserves the intended meaning while making the scenario consistent with the ontology context.',
#   'story_so_far': 'Jack just turned 67 years old and is celebrating his birthday with his family.'},
#  {'step': 2,
#   'original': 'Many people would describe Jack as a reserved person despite him loving to talk about himself.',
#   'updated': 'Many people would describe Jack as an adventurous person despite him being reserved and not necessarily loving to travel.',
#   'consistency': 'Inconsistent',
#   'ontology_used': 'The reserved trait belongs to the category of character traits and implies that someone with this trait would hate meeting people and hate talking.\n\nAdventurous belongs to the category of Character Traits and implies that someone with this trait loves traveling.\n\nThe concept of Social belongs to the category of CharacterTraits and implies that an entity with this characteristic typically enjoys meeting people.\n\nThe instance HatesTalking belongs to the class(es) Behaviour.\n\nBehaviour is a subclass of Thing.',
#   'llm_raw_output': 'Consistency: Inconsistent\nUpdated scenario: Many people would describe Jack as an adventurous person despite him being reserved and not necessarily loving to travel.\nExplanation:\n1. Ontology: "The reserved trait ... hate meeting people and hate talking" implies that someone with this trait does not like social interactions, but Jack is shown enjoying his birthday celebration with family. This contradicts the description of a reserved person.\n2. I changed the descriptor from "reserved" to "adventurous", which aligns with the fact that Jack loves to talk about himself, as people with this trait typically enjoy social interactions, fitting his behavior.',
#   'explanation': '1. Ontology: "The reserved trait ... hate meeting people and hate talking" implies that someone with this trait does not like social interactions, but Jack is shown enjoying his birthday celebration with family. This contradicts the description of a reserved person.\n2. I changed the descriptor from "reserved" to "adventurous", which aligns with the fact that Jack loves to talk about himself, as people with this trait typically enjoy social interactions, fitting his behavior.',
#   'story_so_far': 'Jack just turned 67 years old and is celebrating his birthday with his family.\nMany people would describe Jack as an adventurous person despite him being reserved and not necessarily loving to travel.'},
#  {'step': 3,
#   'original': "Jack's family decided to visit the city of Quito for his birthday celebration.",
#   'updated': "Jack's family decided to visit the city of Quito for his birthday celebration.",
#   'consistency': 'Consistent',
#   'ontology_used': 'Quito belongs to the class of cities and has the following characteristics:\n\nIt has a car ratio of 234.\nIt is located in Ecuador.\nIts population is approximately 2,342,000 people.\n\nLeo belongs to the class of Adults.\nHe works as a Waiter at Riccolo.\nHis age is 23 years old.\n\nLaVirgenDelPanecillo belongs to the class of Landmarks and meets the following criteria:\n\nIt was built in 1975.\nIts height is 41 meters.\n\nIt is located in Quito.\n\nRiccolo belongs to the class of restaurants.\n\nThe property carRatio has the following characteristics:\n\nDomain: It applies to cities.\nRange: Its value must be an integer.',
#   'llm_raw_output': 'Consistency: Consistent\nUpdated scenario: Jack\'s family decided to visit the city of Quito for his birthday celebration.\nExplanation:\n1. Ontology: "Quito belongs to the class of cities" and its characteristics. The story so far does not provide any information that would make visiting Quito inconsistent with the ontology context.',
#   'explanation': '1. Ontology: "Quito belongs to the class of cities" and its characteristics. The story so far does not provide any information that would make visiting Quito inconsistent with the ontology context.',
#   'story_so_far': "Jack just turned 67 years old and is celebrating his birthday with his family.\nMany people would describe Jack as an adventurous person despite him being reserved and not necessarily loving to travel.\nJack's family decided to visit the city of Quito for his birthday celebration."},
#  {'step': 4,
#   'original': 'The city of Quito has a landmark called La Virgen del Panecillo that overlooks the city from a tall hill.',
#   'updated': 'The city of Quito has a landmark called LaVirgenDelPanecillo that overlooks the city from a tall hill.',
#   'consistency': 'Consistent',
#   'ontology_used': 'LaVirgenDelPanecillo belongs to the class of Landmarks and meets the following criteria:\n\nIt was built in 1975.\nIts height is 41 meters.\n\nIt is located in Quito.\n\nQuito belongs to the class of cities and has the following characteristics:\n\nIt has a car ratio of 234.\nIt is located in Ecuador.\nIts population is approximately 2,342,000 people.\n\nThe RedRocksAmphitheatre instance belongs to one or more classes known as Landmark.\nIt was built in 1941.\nIts building height is 1970 meters.\nRedRocksAmphitheatre is located in Denver.\n\nThe property carRatio has the following characteristics:\n\nDomain: It applies to cities.\nRange: Its value must be an integer.\n\nThe Eiffel Tower belongs to the category of Landmarks and has the following characteristics:\n\n* It was built in the year 1887.\n* Its height is 330 meters.\n\nAdditionally, it can be found in Paris.',
#   'llm_raw_output': 'Consistency: Consistent\nUpdated scenario: The city of Quito has a landmark called LaVirgenDelPanecillo that overlooks the city from a tall hill.\nExplanation:\n1. Ontology: "LaVirgenDelPanecillo belongs to the class of Landmarks ... It is located in Quito."\n2. This scenario is consistent with both the ontology context and the story so far because LaVirgenDelPanecillo is indeed a landmark located in Quito, matching the provided information.\n3. The scenario does not require any updates as it aligns with the given facts about LaVirgenDelPanecillo being a landmark in Quito, which is where Jack\'s family is visiting for his birthday celebration.',
#   'explanation': '1. Ontology: "LaVirgenDelPanecillo belongs to the class of Landmarks ... It is located in Quito."\n2. This scenario is consistent with both the ontology context and the story so far because LaVirgenDelPanecillo is indeed a landmark located in Quito, matching the provided information.\n3. The scenario does not require any updates as it aligns with the given facts about LaVirgenDelPanecillo being a landmark in Quito, which is where Jack\'s family is visiting for his birthday celebration.',
#   'story_so_far': "Jack just turned 67 years old and is celebrating his birthday with his family.\nMany people would describe Jack as an adventurous person despite him being reserved and not necessarily loving to travel.\nJack's family decided to visit the city of Quito for his birthday celebration.\nThe city of Quito has a landmark called LaVirgenDelPanecillo that overlooks the city from a tall hill."},
#  {'step': 5,
#   'original': 'Quito is known for being easy to walk through due to its lack of mountainous terrain.',
#   'updated': 'Quito is a WalkableCity due to its lack of mountainous terrain.',
#   'consistency': 'Inconsistent',
#   'ontology_used': 'Quito belongs to the class of cities and has the following characteristics:\n\nIt has a car ratio of 234.\nIt is located in Ecuador.\nIts population is approximately 2,342,000 people.\n\nLaVirgenDelPanecillo belongs to the class of Landmarks and meets the following criteria:\n\nIt was built in 1975.\nIts height is 41 meters.\n\nIt is located in Quito.\n\nThe class WalkableCity is defined as follows:\nIt is a subclass of City.\nIt is equivalent to City and has terrain type which is some FlatTerrain.\n\nEcuador belongs to the class of countries.\n\nMountainousTerrain is defined as:\n- A type of Terrain\n- A type of area with an unknown level of noise, specifically one that is Quiet.',
#   'llm_raw_output': 'Consistency: Inconsistent\nUpdated scenario: Quito is a WalkableCity due to its lack of mountainous terrain.\nExplanation:\n1. Ontology: "The class WalkableCity ... It has terrain type which is some FlatTerrain."\n2. The original scenario states that Quito lacks mountainous terrain, but this alone does not guarantee it is walkable because it only implies the absence of a specific type of terrain (MountainousTerrain), not necessarily the presence of flat terrain.\n3. I updated the scenario to state that Quito is a WalkableCity, which directly satisfies the required terrain condition by being equivalent to City with some FlatTerrain, making its lack of mountainous terrain sufficient for walkability.',
#   'explanation': '1. Ontology: "The class WalkableCity ... It has terrain type which is some FlatTerrain."\n2. The original scenario states that Quito lacks mountainous terrain, but this alone does not guarantee it is walkable because it only implies the absence of a specific type of terrain (MountainousTerrain), not necessarily the presence of flat terrain.\n3. I updated the scenario to state that Quito is a WalkableCity, which directly satisfies the required terrain condition by being equivalent to City with some FlatTerrain, making its lack of mountainous terrain sufficient for walkability.',
#   'story_so_far': "Jack just turned 67 years old and is celebrating his birthday with his family.\nMany people would describe Jack as an adventurous person despite him being reserved and not necessarily loving to travel.\nJack's family decided to visit the city of Quito for his birthday celebration.\nThe city of Quito has a landmark called LaVirgenDelPanecillo that overlooks the city from a tall hill.\nQuito is a WalkableCity due to its lack of mountainous terrain."},
#  {'step': 6,
#   'original': 'Jack suffers from asthma, which makes it difficult for him to walk long distances.',
#   'updated': "Jack's family decided to visit Quito by taking taxis or public transportation so that Jack can easily reach LaVirgenDelPanecillo without exerting himself too much.",
#   'consistency': 'Inconsistent',
#   'ontology_used': 'Asthma is defined as follows:\nIt belongs to the category of Health Conditions.\nIt is associated with having Asthma Inhaler as its medication.\nIt comes with symptoms including Fatigue, Shortness Of Breath, Chest Pain, and Coughing.\n\nCoughing belongs to classes of symptoms. It can be a symptom of asthma and it can be a symptom of flew.\n\nShortnessOfBreath is a symptom that belongs to the class of symptoms. It can be a symptom of anxiety, asthma, and lung cancer.\n\nA ChestPain instance belongs to the classes Pain. A ChestPain instance can be a symptom of Asthma, Breast Cancer, and Lung Cancer.\n\nAnxiety belongs to the category of disorders and has the symptom of shortness of breath.',
#   'llm_raw_output': 'Consistency: Inconsistent\nUpdated scenario: Jack\'s family decided to visit Quito by taking taxis or public transportation so that Jack can easily reach LaVirgenDelPanecillo without exerting himself too much.\n\nExplanation:\n1. Ontology: "Asthma is associated with having Asthma Inhaler as its medication" and "It comes with symptoms including Fatigue, Shortness Of Breath, Chest Pain, and Coughing." Jack has asthma.\n2. Since Jack suffers from asthma, walking long distances would exacerbate his condition. This makes the original scenario inconsistent because it implies that Jack will walk to LaVirgenDelPanecillo.\n3. To resolve this inconsistency, I added a detail about transportation to ensure that Jack can visit LaVirgenDelPanecillo safely and comfortably while managing his asthma symptoms.',
#   'explanation': '1. Ontology: "Asthma is associated with having Asthma Inhaler as its medication" and "It comes with symptoms including Fatigue, Shortness Of Breath, Chest Pain, and Coughing." Jack has asthma.\n2. Since Jack suffers from asthma, walking long distances would exacerbate his condition. This makes the original scenario inconsistent because it implies that Jack will walk to LaVirgenDelPanecillo.\n3. To resolve this inconsistency, I added a detail about transportation to ensure that Jack can visit LaVirgenDelPanecillo safely and comfortably while managing his asthma symptoms.',
#   'story_so_far': "Jack just turned 67 years old and is celebrating his birthday with his family.\nMany people would describe Jack as an adventurous person despite him being reserved and not necessarily loving to travel.\nJack's family decided to visit the city of Quito for his birthday celebration.\nThe city of Quito has a landmark called LaVirgenDelPanecillo that overlooks the city from a tall hill.\nQuito is a WalkableCity due to its lack of mountainous terrain.\nJack's family decided to visit Quito by taking taxis or public transportation so that Jack can easily reach LaVirgenDelPanecillo without exerting himself too much."},
#  {'step': 7,
#   'original': 'Jack brought his medication (antihistamine pills) with him on the trip to manage his asthma symptoms.',
#   'updated': 'Jack brought his EpiPen (an injection of antihistamines) with him on the trip to manage his asthma symptoms.',
#   'consistency': 'Consistent',
#   'ontology_used': 'The antihistamine belongs to the class of pills.\n\nPainkiller belongs to pills.\n\nAllergies is a class that inherits from Disorder. \n\nIt is also a subclass of hasMedication, with the restriction that the medication must be an Antihistamine.\n\nEPIpen belongs to the classes of injection.\n\nInhalation is a subclass of Medication.',
#   'llm_raw_output': 'Consistency: Consistent\nUpdated scenario: Jack brought his EpiPen (an injection of antihistamines) with him on the trip to manage his asthma symptoms.\n\nExplanation:\n1. Ontology context states that "The antihistamine belongs to the class of pills." and "Inhalation is a subclass of Medication", but it\'s more specific that EPIpen is an instance of injection, which implies antihistamines in injection form.\n2. I changed Jack\'s medication from "antihistamine pills" (which would be inconsistent with the EpiPen) to "EpiPen" as per ontology context and preserved intended meaning by implying injection of antihistamines rather than oral intake.',
#   'explanation': '1. Ontology context states that "The antihistamine belongs to the class of pills." and "Inhalation is a subclass of Medication", but it\'s more specific that EPIpen is an instance of injection, which implies antihistamines in injection form.\n2. I changed Jack\'s medication from "antihistamine pills" (which would be inconsistent with the EpiPen) to "EpiPen" as per ontology context and preserved intended meaning by implying injection of antihistamines rather than oral intake.',
#   'story_so_far': "Jack just turned 67 years old and is celebrating his birthday with his family.\nMany people would describe Jack as an adventurous person despite him being reserved and not necessarily loving to travel.\nJack's family decided to visit the city of Quito for his birthday celebration.\nThe city of Quito has a landmark called LaVirgenDelPanecillo that overlooks the city from a tall hill.\nQuito is a WalkableCity due to its lack of mountainous terrain.\nJack's family decided to visit Quito by taking taxis or public transportation so that Jack can easily reach LaVirgenDelPanecillo without exerting himself too much.\nJack brought his EpiPen (an injection of antihistamines) with him on the trip to manage his asthma symptoms."}]

# %%
import json

# Create a combined export dictionary
export_data = {
    "original_story": final_state.get("story", ""),
    "scenarios": final_state.get("scenarios", []),
    "updated_scenarios": final_state.get("updated_scenarios", []),
    "fixed_story": final_state.get("fixed_story", ""),
    "reasoning_results": final_state.get("results", []),  # the detailed reasoning trace
}

# Save it as JSON
with open("story_test_output.json", "w", encoding="utf-8") as f:
    json.dump(export_data, f, indent=2, ensure_ascii=False)

print("Saved everything to story_pipeline_output.json")
# Out:
# Saved everything to story_pipeline_output.json
