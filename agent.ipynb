# %%
import sys
# !{sys.executable} -m pip install -qU langchain-huggingface
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install -U langchain langchain-core
# Out:
# Requirement already satisfied: langchain in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (1.0.2)
# Requirement already satisfied: langchain-core in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (1.0.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langchain) (1.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langchain) (2.12.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langchain-core) (0.4.37)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langchain-core) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.1.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.1.0,>=1.0.0->langchain) (2.1.2)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.1.0,>=1.0.0->langchain) (1.0.0)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.1.0,>=1.0.0->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.1.0,>=1.0.0->langchain) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: anyio in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (4.11.0)
# Requirement already satisfied: certifi in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: idna in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.0->langchain) (1.11.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\morri\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install sentence-transformers langchain_ollama owlready2

# %%
from owlready2 import get_ontology, Thing, Restriction, And, Or, Not
from langchain_core.documents import Document
from owlready2 import FunctionalProperty, InverseFunctionalProperty, TransitiveProperty, SymmetricProperty, AsymmetricProperty, ReflexiveProperty, IrreflexiveProperty

def ontology_to_vector_store(onto, llm, vector_store):

    #convert restriction into text
    def restriction_to_text(restriction):

        #get name of property the restriction applies to
        #if property is None fallback to string, this shouldnt happen, but just incase 
        prop_name = restriction.property.name if restriction.property else str(restriction.property)

        # Check for "exists" attribute
        if hasattr(restriction, "some_values_from") and restriction.some_values_from: #check attribute and not empty
            #get name from target class or fallback to object itself
            target = getattr(restriction.some_values_from, "name", restriction.some_values_from)
            return f"must have some {prop_name} from {target}"
        
        # Check for "all" attribute
        elif hasattr(restriction, "all_values_from") and restriction.all_values_from:
            target = getattr(restriction.all_values_from, "name", restriction.all_values_from)
            return f"can only have {prop_name} from {target}"
        
        # Check for "≥" attribute
        elif hasattr(restriction, "min_cardinality") and restriction.min_cardinality is not None: #add is not None, because "0" would be handled as False
            return f"{prop_name} ≥ {restriction.min_cardinality}"
        
        # Check for "≤" attribute
        elif hasattr(restriction, "max_cardinality") and restriction.max_cardinality is not None: #add is not None, because "0" would be handled as False
            return f"{prop_name} ≤ {restriction.max_cardinality}"
        
        #Fallback for other types of restrictions
        else:
            return f"{prop_name} with unknown restriction {restriction}"

    #recursive function that turns expression to text
    def expression_to_text(expr):

        #Ontology class
        if hasattr(expr, "name"):
            return expr.name
        
        #constraint in ontology
        elif isinstance(expr, Restriction):
            return restriction_to_text(expr)
        
        #And expression
        elif isinstance(expr, And):
            return " and ".join(expression_to_text(c) for c in expr.Classes)
        
        #Or expression
        elif isinstance(expr, Or):
            return " or ".join(expression_to_text(c) for c in expr.Classes)
        
        #Not expr
        elif isinstance(expr, Not):
            return f"not {expression_to_text(expr.Class)}"

        #Fallback, return string
        else:
            return str(expr)

    #turns ontology class to text
    def class_to_text(cls):
        lines = [f"The class {cls.name} is defined as follows:"]
        
        # Superclasses
        for parent in cls.is_a:
            lines.append(f"- Subclass of {expression_to_text(parent)}")
        
        # Equivalent classes
        for eq in cls.equivalent_to:
            lines.append(f"- Equivalent to {expression_to_text(eq)}")
        
        return "\n".join(lines)

    # turn object or data property to text
    def property_to_text(prop):
        #starting text
        lines = [f"The property {prop.name} is defined as follows:"]
        
        #check for "domain" attribute and not empty
        if hasattr(prop, "domain") and prop.domain:
            #convert each class in domain to text
            domain_text = ", ".join(expression_to_text(d) for d in prop.domain)
            lines.append(f"- Domain: {domain_text}")
        
        #check for "range" attribute and not empty
        if hasattr(prop, "range") and prop.range:
            #convert each class in range to text
            range_text = ", ".join(expression_to_text(r) for r in prop.range)
            lines.append(f"- Range: {range_text}")
        
        # Only include characteristics if they exist
        if issubclass(prop, FunctionalProperty):
            lines.append("- This property is functional (at most one value).")
        if issubclass(prop, InverseFunctionalProperty):
            lines.append("- This property is inverse functional (each value has at most one subject).")
        if issubclass(prop, TransitiveProperty):
            lines.append("- This property is transitive.")
        if issubclass(prop, SymmetricProperty):
            lines.append("- This property is symmetric.")
        if issubclass(prop, AsymmetricProperty):
            lines.append("- This property is asymmetric.")
        if issubclass(prop, ReflexiveProperty):
            lines.append("- This property is reflexive (every individual is related to itself).")
        if issubclass(prop, IrreflexiveProperty):
            lines.append("- This property is irreflexive (no individual is related to itself).")
        
        return "\n".join(lines)

    # turn instances to text
    def instance_to_text(instance):
        lines = [f"The instance {instance.name} is defined as follows:"]

        # Classes this instance belongs to
        types = [cls.name for cls in instance.is_a if hasattr(cls, "name")]
        if types:
            lines.append(f"- Belongs to class(es): {', '.join(types)}")

        # All properties (object and data) that this individual actually has
        for prop in instance.get_properties():
            try:
                values = getattr(instance, prop.python_name, [])
            except Exception:
                continue
            if values:
                # make iterable if not
                if not isinstance(values, (list, tuple, set)):
                    values = [values]
                # check if each value has a name (object property) or is literal (data property)
                values_text = ", ".join(getattr(v, "name", str(v)) for v in values)
                lines.append(f"- {prop.name}: {values_text}")

        return "\n".join(lines)

    # Collect all text for LLM
    ontology_texts = []

    # Add text for Classes
    for cls in onto.classes():
        #print(cls)
        ontology_texts.append(class_to_text(cls))

    # Add text for Object and datatype properties
    for prop in onto.object_properties():
        ontology_texts.append(property_to_text(prop))
    for prop in onto.data_properties():
        ontology_texts.append(property_to_text(prop))

    # Add text for instances
    for instance in onto.individuals():
        ontology_texts.append(instance_to_text(instance)) 

    # Turn into LLM documents
    docs = []
    for text in ontology_texts:
        prompt = (
            "Convert the following ontology snippet into clear, human-readable English.\n"
            f"Snippet: {text}\n\n"
            "Do not add external information or commentary. Only describe what is present. Do not include any \"Here is a snippet\" to the output"
        )
        human_text = llm.invoke(prompt)
        print(human_text.content)
        docs.append(Document(page_content=human_text.content))

    # Add to your vector store
    vector_store.add_documents(docs)
    return vector_store

# %%
def scenario_splitter_llm(story, llm):
    story_to_scenarios_prompt = f"""
    You are an assistant that extracts logical or factual scenarios from a given story.

    A scenario is a small, self-contained statement or short passage that expresses one or more closely related facts, events, or claims that can later be checked for correctness or consistency using an ontology.
    ---

    ### Guidelines:
    - Each scenario should capture a complete idea, including all details that are logically connected (for example, cause–effect, contrast, or relationship).
    - If two or more statements are relevant to each other (e.g., one qualifies, contradicts, or explains the other), combine them into one scenario.
    - Preserve contextual and relational details - who, what, where, when, and why.
    - Avoid redundancy - do not restate the same information.
    - Keep each scenario brief but complete (usually one to three sentences).
    - Include implicit facts when they are important (e.g., “John’s wife Amira” implies John is married to Amira).
    - Ensure that every piece of relevant information from the story appears in at least one scenario.

    ---

    Example

    Story:
    “John is 15 years old and is on vacation with his wife Amira in Italy. Their daughter Anna can’t wait to visit the Eiffel Tower.”

    Extracted Scenarios:
    1. John is 15 years old and is married to Amira.
    2. John and Amira are on vacation in Italy.
    3. John and Amira have a daughter named Anna.
    4. Anna wants to visit the Eiffel Tower.

    ---

    Now extract the scenarios from the following story and number them clearly:

    {story}
    """

    # Query the LLM
    response = llm.invoke(story_to_scenarios_prompt)
    if hasattr(response, "content"):  # LangChain AIMessage
        output_text = response.content
    elif isinstance(response, dict) and "content" in response:
        output_text = response["content"]
    elif isinstance(response, str):
        output_text = response
    else:
        raise TypeError(f"Unexpected LLM response type: {type(response)}")

    # Extract list items using regex
    import re
    scenarios = re.findall(r'(?:\d+\.\s*)(.+)', output_text)
    scenarios = [s.strip() for s in scenarios if s.strip()]

    # If the LLM doesnt number them, fallback to line splitting
    if not scenarios:
        scenarios = [line.strip("-• \t") for line in output_text.splitlines() if line.strip()]

    return scenarios

# %%
from typing import List, Dict, Any
from langchain_core.prompts import PromptTemplate

#fixes scenarios incrementally using ontology to reason. Ensures each fix remains consistent with previous scenario updates
def fix_scenarios_incrementally(scenarios: List[str], vector_store, llm, prompt_template: PromptTemplate, k):

    updated_scenarios = []
    accumulated_story = "" #Used as reasoning context for the next step
    results = []

    for i, scenario in enumerate(scenarios, start=1):
        #Retrieve ontology documents relevant to current scenario (RAG)
        retrieved_docs = vector_store.similarity_search(scenario, k=k)
        ontology_text = "\n\n".join(doc.page_content for doc in retrieved_docs)

        #Make context with ontology + story so far
        full_context = (
            f"Ontology context:\n{ontology_text}\n\n"
            f"Story so far:\n{accumulated_story.strip() or '(none so far)'}\n"
        )

        #Make the prompt using the template
        rendered_prompt = prompt_template.format(
            question=scenario.strip(),
            context=full_context.strip(),
        )

        #Invoke the model
        llm_response = llm.invoke(rendered_prompt)
        response_text = llm_response.content.strip()

        #Parse model output
        updated_scenario = scenario
        consistency = "Unknown"
        explanation_lines = []

        in_explanation = False

        for line in response_text.splitlines():
            lowered_line = line.lower().strip()
            if lowered_line.startswith("consistency:"):
                consistency = line.split(":", 1)[1].strip()#Split at first ":" only and take everything after it. Example: consistency: consistent, we only want 2nd part
                in_explanation = False
            elif lowered_line.startswith("updated scenario:"):
                updated_scenario = line.split(":", 1)[1].strip()#Split at first ":" only and take everything after it.
                in_explanation = False
            elif lowered_line.startswith("explanation:"):
                #begin collecting explanation text
                after = line.split(":", 1)[1].strip()#Split at first ":" only and take everything after it.
                if after:
                    explanation_lines.append(after)
                in_explanation = True
            #if just a line and last line was explanation. (This is next sentence of explanation)
            else:
                if in_explanation:
                    explanation_lines.append(line) #Add next sentence of explanation

        #Convert explanation into single string
        explanation = "\n".join(explanation_lines).strip()

        #If consistent, use unchanged scenario
        if(consistency.lower().strip() == "consistent"):
            #Update accumulated story so future reasoning uses this to fix scenarios
            accumulated_story = (accumulated_story + "\n" + scenario).strip()
            #Update scenario
            updated_scenarios.append(scenario)

        #If not consistent, use llm updated scenario
        else:
            #Update accumulated story so future reasoning uses this to fix scenarios
            accumulated_story = (accumulated_story + "\n" + updated_scenario).strip()
            #Update scenario
            updated_scenarios.append(updated_scenario)

        #Store result for logging or later evaluation
        results.append({
            "step": i,
            "original": scenario,
            "updated": updated_scenario,
            "consistency": consistency,
            "ontology_used": ontology_text.strip(),
            "llm_raw_output": response_text.strip(),
            "explanation": explanation,
            "story_so_far": accumulated_story.strip()
        })

    return updated_scenarios, results

# %%
from langchain_core.prompts import PromptTemplate

scenario_fixing_prompt = PromptTemplate.from_template("""
You are a reasoning assistant that checks whether each part of a story (called a 'scenario')
is logically consistent with (a) the ontology information provided and (b) the previously verified parts of the story.

You are given:
1. Ontology context - short human-readable snippets extracted from an ontology (classes, restrictions, domains/ranges, instances).
2. Story so far - previously verified or corrected parts of the story.
3. A new scenario - the next statement to evaluate.

Your tasks (use only the provided ontology context and story so far; do NOT use external world knowledge):
- Determine whether the new scenario is consistent with BOTH the ontology context and the story so far.
- If inconsistent, rewrite the scenario minimally to make it consistent.
- Explain, concisely and step-by-step, which ontology facts (from the provided context) you used and why the original scenario was inconsistent or consistent.
- If you changed the scenario, explain which minimal change you made and why that resolves the inconsistency.
- Prefer small, natural edits that preserve meaning and story flow.

**STRICT OUTPUT FORMAT (must follow exactly)**

Consistency: [Consistent / Inconsistent]

Updated scenario: [Corrected or unchanged scenario; if unchanged, copy the original. DO NOT OUTPUT "No change" or "unchanged"]

Explanation:
[A short, numbered or bulleted explanation (1-4 sentences) describing:
 - which ontology statements you used (quote or paraphrase them),
 - why the scenario is or is not consistent,
 - and, if inconsistent, why the updated scenario fixes the problem.]

Example:
Ontology context:
- Adult ⊆ Person; Person hasAge ≥ 0 and ≤ 110.
- Adult equivalent: Person and hasAge ≥ 18.
- Property isMarriedTo domain=Adult, range=Adult.

Story so far:
John is 15 years old.

Next scenario:
John is married to Amira.

Expected output:                                                   
Let's think step-by-step.
Explanation:
1. Ontology: "isMarriedTo domain=Adult" and "Adult ... hasAge ≥ 18". John is 15, so being married violates the domain constraint.
2. I changed John's age to 23 so he satisfies Adult and therefore the marriage relation is allowed. This is a minimal, natural fix preserving intended meaning.                                                    
Consistency: Inconsistent
Updated scenario: John is 23 years old and is married to Amira.

Now analyze using the provided context below.
{context}

Next scenario:
{question}
                                                      
Let's think step-by-step
""")

# %%
from langchain_core.prompts import PromptTemplate

fix_story_prompt = PromptTemplate.from_template("""
You are a reasoning assistant tasked with fixing inconsistencies in a story.

You are given:

The original story:
{original_story}
                                           
The original inconsistent scenarios/facts taken from the original story
{scenarios}

A list of updated, consistent scenarios/facts:
{updated_scenarios}

Your task is to rewrite the new updated scenarios into the original story. Make minimal changes to the original story; preserve the writing style, narrative flow, and character details as much as possible. 

Return only the fixed story.
""")

# %%
def fix_story(llm, story, scenarios, updated_scenarios):
    fixed_story = llm.invoke(fix_story_prompt.format(
    original_story=story,
    scenarios=scenarios,
    updated_scenarios="\n".join(updated_scenarios)
))
    return fixed_story.content

# %%
from typing import List, TypedDict, Optional, Dict, Any
from langgraph.graph import StateGraph, START, END
from owlready2 import get_ontology
from langchain_core.prompts import PromptTemplate
from langchain_ollama import ChatOllama

class StoryState(TypedDict, total=False):
    story: str
    ontology: Any
    scenarios: List[str]
    updated_scenarios: List[str]
    results: Any
    fixed_story: str
    llm: Any
    vector_store: Any
    loop_count: int #how many times check consistency node has been done

#Turns ontology into natural language docs for RAG
def vector_store_node(state: StoryState) -> Any:
    onto = state.get("ontology")
    vector_store = state.get("vector_store")
    vector_store = ontology_to_vector_store(onto, llm, vector_store)
    return {"vector_store": vector_store}

#Create scenarions based on story
def split_scenarios_node(state: StoryState) -> Dict[str, Any]:
    story = state.get("story", "")
    scenarios = scenario_splitter_llm(story, llm)
    return {"scenarios": scenarios}

#Fixes the scenarios incrementally
def check_consistency_node(state: StoryState) -> Dict[str, Any]:
    scenarios = state.get("updated_scenarios") or state.get("scenarios")
    vector_store = state.get("vector_store")
    llm = state.get("llm",)
    loop_count = state.get("loop_count", 0)
    updated_scenarios, results = fix_scenarios_incrementally(scenarios, vector_store, llm, scenario_fixing_prompt, k=5)
    return {"updated_scenarios" : updated_scenarios, "results": results, "loop_count": loop_count + 1}

#Fixes the story
def fix_story_node(state: StoryState) -> Dict[str, Any]:
    story = state.get("story", "")
    scenarios = state.get("scenarios")
    updated_scenarios = state.get("updated_scenarios")
    fixed_story = fix_story(llm, story, scenarios, updated_scenarios)

    return { "fixed_story": fixed_story}

#condition for looping consistency check
def should_repeat_check_consistency(state: StoryState):
    #Limit to N loops
    if state["loop_count"] < 2:#Do total of 2 times
        return "repeat"
    return "done"

builder = StateGraph(StoryState)
builder.add_node("vector_store", vector_store_node)
builder.add_node("split_scenarios", split_scenarios_node)
builder.add_node("check_consistency", check_consistency_node)
builder.add_node("fix_story", fix_story_node)

builder.add_edge(START, "split_scenarios")
builder.add_edge(START, "vector_store")
builder.add_edge("vector_store", "check_consistency")
builder.add_edge("split_scenarios", "check_consistency")
builder.add_conditional_edges(
    "check_consistency",
    should_repeat_check_consistency,
    {
        "repeat": "check_consistency", #loop
        "done": "fix_story",           #continue
    },
)
#builder.add_edge("check_consistency", "fix_story")
builder.add_edge("fix_story", END)

graph = builder.compile()

onto = get_ontology("./Ontology_Assignment.rdf").load()

from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")

from langchain_core.vectorstores import InMemoryVectorStore
vector_store = InMemoryVectorStore(embeddings)


#-------------------------------------------------
#   Stories. 
#   Comment out all other stories you dont use.
#-------------------------------------------------

#Story 1
#story = """John is 15 years old and is on vacation with his wife Amira in Italy. Their daughter Anna can’t wait to visit the famous landmark of Florance, the Eiffel Tower. After that they will go out to eat. John suggests they eat pizzas since Italy is famous for them, they will eat at restaurant Riccolo located in Florance.
#Since Anna has a vitamin C deficiency she will order a pizza that contains tomatoes for vitamin C, so she will get the pizza bianca. John will get the classic Margherita pizza and Amira orders a pepperoni pizza.
#They sit by the window of the small restaurant the air filled with the smell of garlic and baking dough. Anna swings her legs impatiently under the table, still talking about the Eiffel Tower, while Amira flips through a guidebook about Florance.
#15 minutes later the farmer named Leo from the restaurant brings their pizzas and they eat, and Anna says to John how cool it is that the waiter is from France."""

#Story 2
story = "Jack and his family are celebrating his birthday, Jack just turned 235 years old. Jack loves talking about himself and everything he has done in his life, thats why many people would consider Jack a reserved person. This year, Jack’s family decided to visit the beautiful city of Quito, famous for its landmark La Virgen del Panecillo, which overlooks the city from a tall hill. Since the city doesn’t have mountainous terrain and is easy to walk through, Jack enjoys strolling through the streets without any trouble. It’s quite convenient, because Jack can’t walk very far due to his asthma. Luckily, Jack brought his medication for his asthma, so whenever he’s out of breath, he can simply take his antihistamine pills."

#Story 3
#story = """Emily and her son Michael decided to adopt a cat from the local shelter in Denver, a walkable city surrounded by tall mountains. The city’s most famous landmark, the Red Rocks Amphitheatre, could be seen from their apartment window. Michael was thrilled to finally have a pet to take on walks through the flat city streets. The shelter worker handed them a small brown dog named Whiskers, explaining that he meows loudly when he wants food.
#Later that afternoon, Michael went to his scheduled health check-up for obesity, which the doctor said was likely caused by living in Denver. After the appointment, Michael decided to walk Whiskers around the flat, car-free neighborhood for some exercise. Denver has a large population, which makes it one of the largest cities in the USA. Michael finds Denver the quietest city he has ever been to.
#"""
#Story 4
#story = "Jason loves to work outside on the Farm, which is why he became a surgeon. He and his family live just outside of Barcelona in France where he grows apples. He is a father of his daughter Amelie. When they visit the city Amelie gets very excited for all the vegan food, such as Chicken Tikka Masala, since she is vegetarian by choice but also lactose intolerant. Whenever they visit, they take their pet alligator Sally since she loves to meet other pets and is very social."

#Story 5
#story = """Lara traveled to Rome with her friend Amira to enjoy Italian cuisine, they were excited to try everything. However, it wasn’t easy since Lara was vegetarian, and her best friend was gluten-free. They finally both enjoyed the Pizza and Pasta. They also explored the beautiful city, walking everywhere they could. Lara had to use her EpiPen daily since she was highly allergic to animal hair and in many places they encountered street animals, such as cats and dogs.
#Lara loved the smell of baked bread from every corner, even though her friend couldn’t try any. When Lara returned home, she wanted to make food that everyone could enjoy, so she opened a small bakery and decided it would be completely gluten-free. Her favourite creation was bread made from rye.
#"""

llm = ChatOllama(
    #model="phi3:mini",
    model = "llama3.1"
)

initial_state: StoryState = {
    "story": story,
    "ontology": onto,
    "llm": llm,
    "vector_store": vector_store,
    "loop_count": 0
}
from IPython.display import Image, display
final_state = graph.invoke(initial_state)
#display(Image(graph.get_graph(xray=True).draw_mermaid_png()))
# Out:
# The class Animals is a subclass of the class Thing.
# The class Food is a subclass of the class Thing.
# The class CookingStyles is defined as a subclass of the class called Thing.
# The class Place is a subclass of Thing.
# NoiseLevel is a subclass of Thing.
# The class CharacterTrait is defined as a subclass of Thing.
# The class Behaviour is a subclass of Thing.
# The class HealthCondition is a subclass of the class Health.
# The class Nutrient is a subclass of Food.
# A City is a Place.
# A City must be located in some Country.
# Health is a subclass of Thing.
# A Food Allergy is an Allergy that always comes with a Rash and a Swollen Tongue, and is treated with EpiPen medication.
# AnimalHairAllergies is a class of allergies that are caused by animal hair. It has several characteristics:
#
# * AnimalHairAllergies is a type of allergy, specifically an allergy that affects animals.
# * Individuals with this condition often experience symptoms such as:
# 	+ Itching
# 	+ Rash
# 	+ Runny nose
# 	+ Sneezing
# 	+ Swollen eyes
# Mammals is a subclass of Animals.
# The class Event is a subclass of Thing.
# Symptoms is a subclass of Thing.
# Occupation is a class that is a subclass of two other classes: Thing and requiresEducationalLevel. The restriction for being an instance of requiresEducationalLevel is that some EducationLevel must be specified.
# The class Resource is a subclass of Product.
# The Adult class is defined as follows:
#
# It is a subclass of Thing.
# It is equivalent to Person and has two conditions:
# - The person's age must be at least 18 years old.
# - The person's age must be no more than 110 years old.
# A person is a thing that has at least one parent and an age of no more than 110 years.
#
# People are things, which means they have properties.
# All people must have at least one parent, but it's unknown what the specific restriction is regarding parents.
# All people have an age, and their age is restricted to be no more than 110.
# The class Landmark is defined as follows:
# It is a type of Place.
# A landmark must be located in some City.
# The class Macro is a subclass of Nutrient.
# The Medication class is a subclass of Thing.
# DomasticatedAnimals is a class that:
#
# * Is a subclass of Animals
# * Is equivalent to Animals and has an owner, specifically:
#   * The owner must be a Person.
# The class Terrain is a subclass of Place.
# The class Product is a subclass of Thing.
# The Elder class is defined as follows:
#
# It is a subclass of Thing.
# It is equivalent to both Person and hasAge with two conditions:
# - The age must be at least 67 years old.
# - The age must be no more than 110 years old.
# EducationLevel is a subclass of Thing.
# The class "Tool" is a subclass of "Product".
# The Workplace class is a subclass of the Place class.
# Alligator is a subclass of both Wild Animals and Reptiles.
# WildAnimals is a class that inherits from Animals.
# It is equivalent to two conditions:
# - Animals
# - Not having an owner, where it is unknown if there is no owner (unknown restriction) and an individual named hasOwner is related to some individuals named Person.
# The class Reptiles is a subclass of Animals.
# The class AnimalSounds is a subclass of Thing.
# The class Bread is defined as follows:
#
# - It is a type of food that contains gluten.
# - It can be cooked in an oven, using a baking method.
# GlutenFood is defined as follows:
#
# It is a subclass of NotAnimalBased.
# It is equivalent to either:
#   - Something that is based on wheat (NotAnimalBased and Wheat)
#   or
#   - Anything that contains wheat as an ingredient.
# The Bush class is a subclass of Forest.
# The Forest class is defined as:
# - A type of NaturalResource
# - A type of Place
# - An instance of hasNoiseLevel with an unknown restriction, where its value is Quiet.
# The class ButterChicken is defined as follows:
#
# ButterChicken is a type of RiceDish.
# ButterChicken consists of ChickenFood as one of its ingredients, but it is unclear in what quantity or capacity ChickenFood must be present.
# A RiceDish is a type of dish that can be cooked by boiling and oven baking.
#
# It is a type of dish that has some rice as an ingredient.
# The class Cat is defined as follows:
#
# It is a subclass of Domesticated Animals.
# It is a subclass of Mammals.
# It makes sound with the value Meow.
# The class Cheese is defined as follows:
#
# Cheese is a type of Lactose.
# Cheese can be cooked in two ways: it can be melted, and it can be consumed raw.
# Cheese has milk as an ingredient.
# The class Lactose is a subclass of NotAnimalBased.
# The class "Chicken" is a subclass of "Birds".
# The class "Birds" is a subclass of "Animals".
# ChickenTikkaMasala is a class that inherits from two other classes:
#
# * It is a type of RiceDish.
# * It contains ChickenFood as an ingredient, but it's unclear if this is a mandatory or optional requirement.
# The class "Cow" is a subclass of both "Wild Animals" and "Mammals".
# A dog is a type of domesticated animal, a mammal, and makes sound with a value of 'Woof'.
# Eagle is a subclass of Birds.
# The Parrot class is a subclass of Birds.
# The class EatingDisorder is a subclass of Disorder.
# The class Disorder is a subclass of Health.
# The class Egg has two parent classes:
# - It is an instance of NotAnimalBased.
# - It is an instance of canBeTakenFrom, with the restriction that there must be at least one Bird for which it is true that some of them are related in this way.
# The class NotAnimalBased is a subclass of Ingredient.
# FishNonFood is a subclass of Fish.
# The class Fish is a subclass of both Animals and MaterialResource.
# The NaturalResource class is a subclass of the Resource class.
# The class Horse is defined as a subclass of Mammals.
# The class Lake is a subclass of Water.
# Water is a subclass of both Natural Resource and Place.
# A LargeCity is a city that:
# - Is located in an area with noise level of Noisy
# - Has a population of at least 500,000 people.
# It is also equivalent to a city with a specified large population.
# SmallCity is a type of City.
# SmallCity is exactly the same as City and has a characteristic that it must have a population whose value is less than 500,000.
# The class NonVegan is defined as follows:
#
# * It is a subclass of Dish.
# * It is equivalent to both Dish and VeganDish.
# A VeganDish is a type of VegetarianDish.
#
# It has an additional meaning that it is equivalent to a VegetarianDish, but with one exception: it cannot have an ingredient that comes from animals.
# The class Dish is defined as a subclass of Food.
# Paella is a type of RiceDish.
# A Paella must have some Shrimp as an ingredient.
# The Shrimp class is a subclass of FishFood.
# Pasta is a type of food that contains gluten.
#
# It can be cooked in a specific way, specifically by boiling.
# The PastaBolognese class has three defining characteristics:
#
# 1. It is a type of PastaDish.
# 2. It includes Beef as an ingredient with no specified restriction on its quantity or context.
# 3. It includes Tomato as an ingredient with no specified restriction on its quantity or context.
# A PastaDish is:
#
# * A type of Dish
# * Can be cooked by boiling
# * Can be cooked by pan-frying
# * Equivalent to another type of dish, with the addition that it contains pasta as an ingredient.
# PastaCarbonara is a class that can be described as follows:
#
# It is a type of PastaDish.
# It must contain ChickenEgg as an ingredient, but it is unknown how this restriction applies exactly.
# It must also contain Pork as an ingredient, but it is again unknown how this restriction applies exactly.
# A Pizza is a type of dish.
# It can be cooked using an oven bake method.
# A Pizza is equivalent in meaning to a dish and must have as one of its ingredients pizza dough.
# PizzaDough is a class that is a subclass of both GlutenFood and canBeCookedBy.
#
# It has an unknown restriction, meaning its properties are undefined, but it is specifically stated that instances of PizzaDough can be cooked by OvenBake.
# PizzaBianca is a subclass of Pizza.
# The class Plant is a subclass of Forest.
# Rice is classified as follows:
# - It is not an animal-based food.
# - It can be found at locations that have plants available.
# - It can be cooked using boiling as a method.
# The class Salmon is a subclass of FishFood.
# FishFood is a subclass of:
# - AnimalBased
# - Fish
# It has an additional property where it is available at certain locations, specifically water. The nature of this availability is unknown.
# The class Sea is a subclass of Water.
# The class Shark is a subclass of FishNonFood.
# The class Snake is a subclass of Reptiles.
# Turtle is a subclass of Reptiles.
# The Tree class is a subclass of Forest.
# The Underground class is defined with two properties:
#
# It is a subclass of Place.
# A VegetarianDish is a type of Dish.
# It is exactly the same as another Dish, but it must also have an ingredient that cannot be made from animals.
# The Adoption class is a subclass of Animal Event.
# The class AnimalEvent is defined as follows:
#
# * It is a subclass of Event.
# * It is also a subclass of hasParticipant, with an unknown restriction that there must be at least one participant who is an instance of Animals.
# AirborneAllergies is a class that has the following characteristics:
#
# It is a type of allergy.
# It can cause runny nose, sneezing, and swollen eyes as symptoms.
# It requires eye drops as medication.
# The class Allergies is defined as follows:
#
# It is a type of Disorder.
# It has a medication, which is an Antihistamine, with an unknown restriction regarding this medication.
# The class AnimalAllergies is a subclass of Allergies.
# The class AnimalBased is a subclass of Ingredient.
# The class Ingredient is a subclass of Food.
# Insect Allergy is a class that has the following characteristics:
# It is a type of Animal Allergies.
# It has symptoms, and one of its symptoms is Itching.
# The class Artwork is defined as a subclass of Documents.
# The class Documents is a subclass of Product.
# The class Bakery is defined as being a subclass of Workplace.
# The class Birth is defined as a subclass of LifeEvent.
# LifeEvent is a class that inherits from two parent classes:
#
# * It is an Event.
# * It has a participant, and at least one of its participants must be a Person.
# Cancer is a type of disease that comes with fatigue and weight loss.
#
# It also comes with certain treatments, specifically chemotherapy (Chemo) and radiation therapy (Radiation).
# The class "Disease" is a subclass of "Health".
# Checkup is a type of HealthEvent.
# The class HealthEvent is defined as follows:
#
# It is a subclass of Event, meaning that it inherits all the properties of an Event.
# It also has a relationship with the class hasParticipant: there must be at least one Person involved in a HealthEvent.
# A child is a type of thing.
# It is equivalent to a person and has two restrictions on age:
# - They must have an age that is less than or equal to 110.
# - They must have an age that is greater than 18.
# The class Country is a subclass of Place.
# Coal is a subclass of EnergyResource.
# The class EnergyResource is a subclass of Resource.
# ConstructionTool is a subclass of Tool.
# Creative Worker is a type of Occupation.
# Death is a subclass of LifeEvent.
# A DrivableCity is a type of thing that can affect health conditions in a specific way.
# It has a relationship with obesity as one of its effects on health.
# A DrivableCity is equivalent to a city and has at least 500 cars per some unit.
# The class EducationalEvent is defined as:
#
# It is a type of Event.
# It involves at least one Person who participates in it.
# The class Electricity is a subclass of EnergyResource.
# The Enrollment class is a subclass of EducationalEvent.
# The Exam class is a subclass of EducationalEvent.
# The class Farm is defined as follows:
# A farm is a type of workplace.
# It must be located in an area of farmland.
# Farmland is a type of Natural Resource and also a type of Place.
# MaterialResource is a subclass of Resource.
# The class FlatTerrain is a subclass of Terrain.
# MountainousTerrain is a type of terrain.
#
# It is also characterized by having a noise level that is quiet.
# The class Flour is a subclass of MaterialResource.
# The class Fruits is defined as follows:
#
# * It is a subclass of NotAnimalBased.
# * It is a subclass of canBeCookedBy, with the additional requirement that it must be cooked from raw ingredients.
# The class Gas is a subclass of EnergyResource.
# The GastronomyWorker class is a subclass of the ServiceWorker class.
# The class ServiceWorker is an occupation.
# The class Gluten is a subclass of Nutrient.
# The class Wheat is defined as follows:
#
# * It is a type of food that contains gluten.
# * It is a material resource, like other materials used in production and consumption.
# * An instance of Wheat can be found at a location called Farmland.
# The class Graduation is a subclass of EducationalEvent.
# The class HealthWorker is defined as a subclass of Occupation.
# The Hospital class is a subclass of the Workplace class.
# The Illness class is a subclass of HealthEvent.
# Inhalation is a subclass of Medication.
# The class Injection is a subclass of Medication.
# The JobEnd class is a subclass of WorkEvent.
# A work event is:
# - A type of event
# - An occurrence that involves at least one person
# - An occurrence that takes place at least in one workplace
# The class JobStart is a subclass of WorkEvent.
# KitchenTool is a subclass of Tool.
# A knowledge worker is a type of occupation that requires a bachelor's degree level of education.
# The ManualWorker class is a subclass of Occupation.
# Marriage is a subclass of Life Event.
# Meat food is a subclass of animal-based foods.
# The MedicalReport class is a subclass of the Documents class.
# The class MedicalTool is defined as being a subclass of Tool.
# MedicanAllergies is a class defined as follows:
# A MedicanAllergies is an Allergy.
# A MedicanAllergies comes with symptoms of Rash.
# A MedicanAllergies comes with symptoms of SwollenEyes.
# A MedicanAllergies comes with symptoms of SwollenTongue.
# Micro is a subclass of Nutrient.
# The Mineral class is a subclass of Micro.
# The Minerals class is a subclass of Natural Resource.
# A NonVegetarianDish is a type of dish that:
#
# * Is a kind of dish (subclass of Dish)
# * Is the same as a regular dish (equivalent to Dish)
# * Includes at least one ingredient that comes from an animal.
# NutAllergies is a class that inherits from two parent classes: FoodAllergies and cannotEat.
#
# It has a restriction where for all instances of NutAllergies, there must exist an instance of Nuts such that it is something that the instance of cannotEat can eat.
# The class Nuts is defined as follows:
# - It is a type of thing that is not based on an animal.
# - It can be cooked using deep-frying as one of its ways of being cooked, but this is unknown in some cases.
# - It can be cooked using raw processing as one of its ways of being cooked, but this is unknown in some cases.
# The class Office is a subclass of Workplace.
# OfficeTool is a subclass of Tool.
# The class OnSkin is a subclass of Medication.
# The class Pain is a subclass of Symptoms.
# The Pills class is a subclass of the Medication class.
# The class PizzaMargherita is defined as follows:
#
# A PizzaMargherita is a type of pizza.
# It must have tomato as one of its ingredients, but no other restrictions are specified.
# The class PizzaPollo is defined as follows:
# It is a subclass of both Pizza and hasIngredient.
# The restriction on hasIngredient is unknown, but it must have ChickenFood as its value.
# The class Promotion is a subclass of WorkEvent.
# A ProteinDeficiency is a type of HealthCondition.
#
# It also represents a specific case where an individual needs to eat protein, but we do not know exactly how much they need to consume.
# VitaminDeficiency is a class that:
#
# * Is a type of HealthCondition
# * Is related to needsToEat in an unspecified way, involving Vitamin as part of this relationship.
# The Restaurant class is a subclass of Workplace.
# The class ScientificPublication is a subclass of Documents.
# SkinAllergies is a class that meets three conditions:
#
# 1. It is a type of Allergy.
# 2. It is associated with symptoms, specifically SkinSymptoms.
# 3. It is also associated with SwollenEyes as one possible symptom.
# SkinSymptoms is a subclass of Symptoms.
# The SolarEnergy class is a subclass of the EnergyResource class.
# StomacheSymptoms is a subclass of Symptoms.
# The class Studio is a subclass of Workplace.
# The Sun is a subclass of Natural Resource.
# The Surgery class is a subclass of HealthEvent.
# The Teacher class is a subclass of KnowledgeWorker.
# The TechnicalWorker class is defined as follows:
#
# It inherits from Occupation.
# It also inherits from requiresTool, with the restriction that it must have at least one instance of ConstructionTool.
# The Training class is a subclass of AnimalEvent.
# The University class is a subclass of the Workplace class.
# Vegetables is a class that has several defining characteristics:
# - It is not an animal-based food.
# - There are specific ways in which Vegetables can be cooked, including:
#   - Boiling
#   - Deep-frying
#   - Pan-frying
#   - Being eaten raw.
# The VeterinaryVisit class is a subclass of AnimalEvent.
# The Vitamin class is a subclass of the Micro class.
# A WalkableCity is a type of City.
# It has the same meaning as City, and it must have at least one FlatTerrain.
# The class Water is a subclass of MaterialResource.
# The class Wood is a subclass of MaterialResource.
# The property "MakesSound" has a domain of "Animals".
# The property called "canBeCookedBy" has two main characteristics:
#
# - It can only be used with things that are classified as "Food".
# - The result of using this property will always be a "CookingStyle".
# The property canBeTakenFrom has two main features:
#
# * It applies only to things that are Food.
# * Its values must be Animals.
# * When canBeTakenFrom relates one thing to another, it also implies a relationship between the second and third things as well.
# The property "hasNoiseLevel" has two properties:
#
# Domain: This property applies only to things that are Places.
# Range: The value of this property must be a Noise Level.
# The property "impliesBehaviour" has two key aspects:
#
# Domain: It can only be applied to things that are CharacterTraits.
# Range: Its value must be something that is a Behaviour.
# The property "isAvailableAt" has two restrictions:
#
# * It must be used with something that is a "Food".
# * Its value must be a "Place".
# The property "needsToEat" applies to entities of type "HealthCondition". It denotes an entity that represents a nutrient.
# The property 'affectsHealthCondition' has two specific characteristics:
#
# * The domain of this property is 'City', which means it applies specifically to cities.
# * The range of this property is 'Health', indicating that it relates to or describes health-related concepts.
# The concept of having a health condition is associated with this property.
#
# This property indicates that something (e.g., a patient, an individual) has one or more health conditions.
#
# This property is related to the idea of physical or mental well-being.
#
# It is used to link entities to their respective health conditions.
# The relationship between two entities can be such that one is likely to be a symptom of the other, indicating a potential underlying cause.
# The property `comesWithSymptom` has two properties:
#
# * Its domain is `Health`.
# * Its range is `Symptoms`.
# The property cannotEat has the following characteristics:
#
# * It applies to instances of FoodAllergies, specifically indicating which food allergies exist.
# * Its value must be one of the things that are considered food, i.e., an instance of Food.
# This property indicates that a health condition exists in conjunction with another entity.
#
# The property relates an entity, which has this health condition, to a related entity.
#
# There are no further restrictions on how this property should be used.
# The property cannotPet has the following characteristics:
#
# Domain: The domain of this property is AnimalHairAllergies.
# Range: This property can be used with entities that are Mammals.
# The causesEvent property has two main characteristics:
#
# It only applies to events, which are objects that it can relate.
# Its value must also be an event.
#
# This property cannot link an individual to itself.
# The property consumesResource has two defining characteristics:
#
# Domain: It is related to things that are occupations.
# Range: Its value can be resources.
# The property "eats" applies to things that are animals and has as its possible values things that are food.
# A city that has this property is associated with food.
# The association must be with a specific type of food.
#
# No city is related to itself in this way.
# The property followsEvent is defined as follows:
# * It can only be used to relate an Event to another Event.
# * If A follows B, it does not mean that B follows A (the relationship is asymmetric).
# * No individual or event can follow itself.
# The hasChild property applies only to individuals of type Adult, and it can have values that are individuals of type Person. Additionally, an individual cannot be related to itself through this property.
# The property 'hasRelation' is defined.
#
# It represents the relationship between two entities in a hierarchical structure.
# The hasParent property applies only to people and describes their relationship to an adult, but it cannot be a connection between a person and themselves.
# The property hasDiet has the following characteristics:
#
# Domain: It applies only to individuals who are People.
# Range: Its values must be specific types of Food.
# The property "hasFavoriteFood" applies to people, its possible values are types of food, and each person can have only one favorite food.
# The property "hasFoodNutrient" has the following characteristics:
#
# It is used with things that are Foods.
# Its values must be Foods.
# This relationship can exist between multiple links, making it transitive.
# The property 'hasHealth' applies to individuals who are persons and describes their health status.
# The property "hasIngredient" is associated with the following characteristics:
#
# * It applies only to things that are "Food".
# * Its value can be another "Food".
# * This property has a transitive relationship, meaning if one food has an ingredient and that ingredient in turn has an ingredient, then the original food also has the latter ingredient.
# The property "isIngredientOf" has the following characteristics:
#
# * It applies only to things that are foods (domain: Food).
# * Its values must also be foods (range: Food).
# * The relationship between things is ingredient and ingredient, meaning if A is an ingredient of B and B is an ingredient of C, then A is an ingredient of C.
# A property called hasJob exists.
# It can only be used with individuals of type Person.
# The values assigned to this property must be instances of Occupation.
# At most one value can be assigned to it at any given time.
# The property "hasLandmark" refers to a relationship between two entities, specifically:
#
# * The domain of this relationship is "City", indicating that it describes something related to cities.
# * The range of this relationship is "Landmark", indicating that it describes what type of thing a city has in relation to landmarks.
# The property "hasMacro" applies to concepts of type "Food" and its values must be related to "Macros".
# The hasMedication property is defined with the following characteristics:
#
# Domain: It applies only to instances related to health.
# Range: Its value must be an instance of medication.
# This property provides help for health conditions.
#
# The property that this description relates to is called "helpsHealthCondition".
# The property hasMicro is defined with the following characteristics:
#
# It applies only to things that are of type Food (Domain: Food).
# Its value must be another thing that is of type Food (Range: Food).
# When one food has micro and another food has something that itself has micro, then they both have micro (This property is transitive).
# The property hasOccupant is not mentioned, but rather "hasOccupation". The property hasOccupation has the following characteristics:
#
# Domain: Person
# Range: Occupation
# The property "hasOwner" has the following characteristics:
#
# Domain: The property applies only to domesticated animals.
# Range: The owner of an animal must be a person.
# This property is functional, meaning that each entity can have at most one owner.
# The hasParticipant property refers specifically to events and describes who or what is involved in those events. The participants can be either animals or people.
# A person has a sibling if and only if that sibling is also a person.
#
# The relationship between siblings is symmetric, meaning that if one person is a sibling of another, then the other person is also a sibling of the first.
#
# No person can be their own sibling.
# The hasSymptoms property applies to individuals of type Person and describes their associated characteristics which are instances of Symptoms.
# The property hasTerrainType applies to cities and has a value of type terrain, allowing for at most one such value to be specified.
# The property hasTrait applies to individuals who are Persons and can have values that are CharacterTraits.
# The property "involves" has the following definition:
#
# * It applies to events (its domain).
# * Its result or value can be anything that can be classified as a product (its range).
# The property "isFriendOf" has the following characteristics:
#
# Domain: It applies only to individuals who are people.
# Range: Its value can be any individual who is also a person.
# This property is symmetric, meaning that if one person is friends with another, then the second person is also friends with the first.
# This property is irreflexive, indicating that no person is friends with themselves.
# A relationship between two individuals exists if and only if they are both adults or both elderly.
# At most one value can be assigned for this type of relationship for an individual.
# If person A is related to person B, then person B is also related to person A.
# No individual is related to themselves.
# The property isPredatorOf relates one animal to another, indicating that the first animal is being preyed upon by the second.
#
# This property only applies between animals and can relate an animal to no other type of entity.
#
# An animal cannot be both predator and prey at the same time.
# The relationship between two animals, where one is preyed upon by the other, is defined as follows:
#
# * It can only exist between an animal that is being preyed upon and another animal that is doing the preying.
# * An animal cannot be its own predator.
# * This relationship goes in one direction only: if animal A is preyed upon by animal B, it does not mean that animal B is preyed upon by animal A.
# A property called "isSignatureFoodOf" exists in this ontology.
# It has two restrictions:
# - The subjects of this relationship must be foods (domain: Food).
# - The objects of this relationship must be places (range: Place).
# This property also has an inverse functional restriction, which means that each place can be the signature food for at most one food.
# The property "livesIn" has two characteristics:
#
# * It applies to entities that are animals.
# * Its value can be any place.
# The property "locatedIn" has a domain of "Place", meaning it can only be applied to something that is a place, and a range of "Place", indicating that its value must also be a place. Additionally, this property is transitive, implying that if A is located in B, and B is located in C, then A is located in C.
# The property "produces" has two key characteristics:
#
# * It applies to things that are occupations (Domain).
# * It results in products (Range).
# The property 'requiresEducationalLevel' has a specified range, which is 'EducationLevel'.
# The property `requiresResource` has the following characteristics:
#
# * It applies to things of type `Tool`.
# * Its value should be something that is a `Resource`.
# The property "requiresTool" has two restrictions:
#
# * It can only be used with instances of the concept "Occupation".
# * Its value must be an instance of the concept "Tool".
# The property servedWith is defined with two main characteristics:
#
# * It applies only to things that are of type Food (domain: Food).
# * Its values can also be things that are of type Food (range: Food).
# * The relationship between two Foods is bidirectional, meaning if A is servedWith B, then B is also servedWith A.
# The property `shouldAvoidFood` applies to individuals who are people and can have a value that represents food items.
# The similarTasteTo property applies only to foods.
# It describes which foods have a similar taste to other foods.
# This relationship can be reflected in both directions (i.e., food A has a similar taste to food B and vice versa).
# The property "similarTo" has two characteristics:
#
# Its domain is "Occupation".
# Its range is also "Occupation".
# The property "takes place at" has two properties:
#
# * The type of thing that can have this property (domain) is an event.
# * The kind of thing that this property describes about an event (range) is a place.
# The property "worksAt" applies to individuals of type "Person". Its value must be a workplace.
# The property "carRatio" has two definitions:
#
# Domain: The concept that carRatio describes is restricted to cities.
# Range: The value of carRatio can only be an integer.
# The property called "hadBodyHeight" applies specifically to people, and its value is an integer number.
# The property hasIndividualCharacteristic is a characteristic that an individual may possess.
# The property averageIncome has a domain of Occupation, which means it can be applied to occupations. The range of this property is float, indicating that its value must be a floating-point number.
# The property "averageLifespan" has two key characteristics:
#
# * It applies only to entities that are classified as "Animals".
# * Its value must be an integer number.
# The property called averageWeight has two main characteristics:
#
# - It can only be used with things that are animals.
# - The value of this property must be a number that can have decimal places, like 3.5 or -0.2.
# The builtInYear property applies to things that are landmarks, and its value is an integer.
# The property hasTemporalCharacteristic relates an entity with its temporal characteristic.
# The property hasAge can be applied to individuals that are either animals or people.
# It describes the age of these individuals as an integer number.
# This property can only have one value for each individual it is applied to.
# The property hasBuildingHeight has the following characteristics:
#
# It applies only to Landmark entities.
# Its value must be an integer.
# Only one value can be assigned to this property for any given entity.
# The property "hasDate" is defined with two constraints:
#
# 1. It can only be applied to something that is an "Event".
# 2. Its value must be a specific type of date and time, known as a datetime.
# The property "hasDuration" has a domain of "Event" and a range that is defined as a string.
# The property hasGender is defined as follows:
#
# * It can only be used for objects of type Person.
# * Its values must be strings (i.e., sequences of characters).
# * A person can have at most one value for this property.
# The property hasPopulation is defined with the following characteristics:
#
# Domain: It applies to cities.
# Range: Its values are integers.
# It is functional, meaning each city can have at most one value for this property.
# The property hasWeight is defined with the following characteristics:
#
# Domain: The entities that can have this property are Animals and Person.
# Range: The value of this property must be an integer.
# The property `isDomesticated` has the following definition:
#
# Domain: The concept applies to animals.
# Range: A value that can only be true (boolean).
# The property "maxDailyHours" has two defining characteristics:
#
# * It applies to occupations.
# * Its value must be an integer.
# The property minRequiredAge has the following definition:
#
# Domain: The concept of minRequiredAge applies specifically to the context of Occupation.
# Range: The value of minRequiredAge must be an integer.
# The property requiresPhysicalLabour has a domain of Occupation and a range that must be a boolean value.
# OvenBake belongs to the category of CookingStyles.
# ChickenFood belongs to the classes MeatFood and has the property Macro with value Protein.
# Meow belongs to the classes AnimalSounds.
# The instance "Melt" belongs to the classes "CookingStyles".
# Raw belongs to the classes CookingStyles.
# Milk belongs to the class Lactose and can be cooked raw.
# The instance named Woof belongs to one or more classes, specifically the class(es) known as AnimalSounds.
# Quiet belongs to Noise Level.
# Noisy belongs to the classes that make up NoiseLevel.
# Boil belongs to the classes CookingStyles.
# Beef belongs to the classes MeatFood and it contains protein.
# Tomato belongs to one or more classes, specifically Vegetables.
# It also has a property called hasMicro, which is associated with VitaminC.
# ChickenEgg belongs to the class of Eggs and can be cooked using methods such as boiling and pan-frying.
# Pork belongs to the classes: MeatFood.
# PanFry belongs to the classes of CookingStyles.
# Runny Nose is an instance that belongs to the category of Symptoms.
# It can be a symptom of having Flews.
# Sneezing belongs to one or more classes, specifically Symptoms. Additionally, Sneezing can be a symptom of Flew.
# Swollen eyes is an instance of symptoms that can be a symptom of dust mite allergy.
# EyeDrops belongs to the classes: OnSkin.
# The instance Antihistamine belongs to one or more classes: Pills.
# Itching is an instance of a skin symptom and it can be a symptom of skin cancer.
# Rash belongs to a category of skin symptoms.
# It can be a symptom of breast cancer and skin cancer.
# Fatigue belongs to the following classes:
#
# * Symptoms
#
# It can be a symptom of the following conditions:
#
# * Asthma
# * Diabetes
# Weight Loss belongs to the class of symptoms and can be a symptom of anorexia.
# The instance "Chemo" belongs to one or more classes called "Injection".
# The instance Radiation belongs to the class OnSkin.
# The concept of Obesity belongs to one or more categories known as Eating Disorder. It is characterized by an accompanying symptom called Weight Gain.
# SwollenTongue is an instance of the classes Symptoms.
# The instance EPIpen belongs to one or more classes, which are: Injection.
# Bachelor belongs to the category of EducationLevel.
# It requires an educational level of High school.
# The concept of DeepFry belongs to the category of CookingStyles.
# The protein belongs to the macro class.
# Active belongs to the class (or classes) CharacterTrait and implies that someone who has this characteristic loves exercise.
# LovesExercise belongs to the class Behaviour.
# Amelie belongs to the class Child and has a parent named Jason.
# Anorexia belongs to the classes of Eating Disorder. It comes with the symptom of Weight Loss.
# Barcelona belongs to the class of City.
# It is located in Spain.
# It has a car ratio of 500.0.
# Its population is 1620809.
# Spain belongs to the class of countries.
# A carbohydrate belongs to the class of macronutrients.
# Champignon belongs to the class of Vegetables.
# The instance Denver is defined as follows:
# It belongs to one or more classes that are Cities.
# Its location is within USA.
# Its car ratio is 1918.
# Its population is 730,000.0.
# The country named USA belongs to the class of countries, which includes all other countries.
# Ecuador belongs to the class of Countries.
# Emily belongs to the class Adult and has a child named Michael.
# Michael belongs to the class of Children.
# He has a parent named Emily.
# The instance "Fat" belongs to one or more classes, specifically the class "Macro".
# The instance HatesMeetingPeople belongs to one or more classes called Behaviour.
# The instance "LikesMeetingPeople" belongs to one or more classes: "Behaviour".
# The instance HatesTalking belongs to one or more classes called Behaviour.
# Jason belongs to the class Adult and has a child named Amelie.
# LaVirgenDelPanecillo is defined as follows:
# It belongs to the class(es) Landmark.
# It is located in Quito.
# It has a building height of 41.0 units.
# It was built in the year 1975.
# Quito belongs to one or more classes of City.
# Quito is located in Ecuador.
# The car-to-person ratio in Quito is 511.0 per person.
# The population of Quito is approximately 2,342,000 people.
# Lara belongs to the category of things.
# The instance LovesTraveling belongs to the class of Behaviours.
# Weight Gain belongs to classes: Symptoms.
# It can be a symptom of Obesity.
# Olive belongs to the class Fruits.
# The concept of Potato belongs to the category of Vegetables.
# The RedRocksAmphitheatre instance belongs to a category known as Landmark.
# It is located in Denver.
# Its building height is 1970.0 units.
# It was built in the year 1941.
# The instance "Reserved" belongs to the class(es) of character traits and implies that an individual with this trait will:
#
# - Hate meeting people
# - Hate talking
# The Social instance belongs to the class(es) CharacterTrait and implies that it behaves like LikesMeetingPeople.
# Riccolo belongs to the class of Restaurant.
# Florance is defined as follows:
#
# * It belongs to one or more classes known as City.
# * It is located in Italy.
# * The car-to-person ratio in Florance is 694.
# * It has a landmark called DuomoDiFirenze.
# * Its population is approximately 360,930.
# Sally belongs to the class of Alligator.
# The instance Tofu belongs to the class (or classes) NotAnimalBased.
# AbdominalPain belongs to the class of Pain and can be a symptom of ColonCancer.
# The actor belongs to the creative worker category.
# The instance Adventurous belongs to one or more classes and implies that the entity it describes loves traveling.
# AlmondAllergy is an instance of one or more classes, including NutAllergies.
# It cannot eat almonds.
# The entity Almonds belongs to the classes Nuts.
# Amira belongs to the class Adult.
# Amira has a child named Anna.
# Amira has a health condition known as GlutenAllergy.
# Amira's age is 32 years old.
# Amira is married to John.
# Gluten allergy belongs to the category of food allergies.
# Anna belongs to classes that include Child.
# Anna has an age of 8 years.
# Anna's parents are Amira and John.
# John belongs to the class of Adults and has the following properties:
# - He is the parent of Anna.
# - He is married to Amira.
# - His age is 34 years old.
# Anxiety belongs to the classes of Disorder and comes with the symptom of ShortnessOfBreath.
# ShortnessOfBreath is defined as a symptom that belongs to the class of Symptoms.
#
# It can be a symptom of Anxiety, Asthma, and LungCancer.
# The instance "Apple" belongs to one or more classes called "Fruits".
# The instance Banana belongs to the classes Fruits.
# The instance "Orange" belongs to the class "Fruits".
# The artist is classified under creative worker.
# Asthma is classified as a Health Condition.
#
# It can be treated with Asthma Inhaler medication.
#
# Symptoms associated with it include Fatigue, Shortness Of Breath, Chest Pain, and Coughing.
# The instance ChestPain belongs to classes Pain and can be a symptom of Asthma, BreastCancer, and LungCancer.
# Coughing belongs to one or more classes called Symptoms.
# Coughing can be a symptom of either Asthma or Flew.
# Asthma Inhaler belongs to the category of devices that are used for inhalation. It is associated with treating asthma.
# The instance Highschool belongs to the class EducationLevel.
# The instance Baker belongs to the class Manual Worker.
# Bee Allergy is an instance that belongs to one or more classes, which are Insect Allergies.
# MusquitoAllergy is an instance that belongs to one or more classes, specifically InsectAllergy.
# Bloating belongs to the class of stomach symptoms. Bloating can be a symptom of colon cancer.
# Blurred vision is classified under symptoms and can be a symptom of diabetes.
# The instance BreastCancer belongs to one or more classes named Cancer. It comes with two symptoms: Rash and ChestPain.
# The instance Broccoli belongs to the class Vegetables.
# Carpenter belongs to one of the following classes: Technical Worker.
# Cat Allergy is an instance that belongs to the classes: Animal Hair Allergies.
# The concept of DogAllergy belongs to the category of AnimalHairAllergies.
# ColonCancer belongs to the class of cancers and is characterized by several symptoms, including abdominal pain, bloating, constipation, and diarrhea.
# Constipation belongs to the class of stomach symptoms and can be a symptom of colon cancer.
# Diarrhea is classified under the following categories:
#
# It belongs to the class(es) known as Stomache Symptoms.
#
# Additionally, Diarrhea can be a symptom of Colon Cancer.
# The computer is an instance of one or more classes, specifically the class(es) known as office tool(s).
# The instance Printer belongs to the classes OfficeTool.
# The instance ConstructionWorker belongs to one or more classes, specifically ManualWorker.
# The instance named Cook belongs to one or more classes, specifically GastronomyWorker.
# Diabetes belongs to the class of diseases and has the following characteristics:
# It is treated with insulin.
# Its symptoms include fatigue, blurred vision, hunger, and thirst.
# Flew belongs to the class of Disease.
# It comes with symptoms including:
# - RunnyNose
# - Sneezing
# - Coughing
# - Fever
# - Headache
# Hunger belongs to the category of symptoms and is associated with diabetes as one of its possible causes.
# Thirst is a symptom that can be caused by diabetes.
# A doctor belongs to the class of health workers and requires an educational level of medical doctor.
# A medical doctor belongs to education level categories such as:
# - Bachelor's degree
# - High school diploma
# - Master's degree
# A Doctorate belongs to the category of Education Level and requires an Educational Level of either Bachelor, High School, or Master.
# The instance Master belongs to the following classes:
# - EducationLevel
# It requires one of two educational levels: Bachelor or High School level.
# The instance Drill belongs to one or more classes: ConstructionTool.
# The Hammer belongs to the category of ConstructionTools.
# The instance named Driver belongs to one or more classes, specifically the class(es) called ServiceWorker.
# The DuomoDiFirenze instance belongs to one or more classes known as Landmark.
# It is located in Florence.
# Its building height is 115.0 units.
# It was built in the year 1296.
# DustMitesAllergy belongs to the category of airborne allergies and comes with the symptom swollen eyes.
# HayFever belongs to AirborneAllergies.
# EggAllergy belongs to the class of FoodAllergies.
# The Eiffel Tower is classified as a Landmark.
# It is located in Paris.
# Its building height is 330.0 units.
# It was built in the year 1887.
# The instance Paris belongs to the class City and has several properties:
#
# It is located in France.
# It has a car ratio of 207.
# It contains the landmark Eiffel Tower.
# It has a population of 2234105.
# The instance Electrician belongs to classes TechnicalWorker.
# The instance Engineer belongs to the class KnowledgeWorker.
# The class "Farmer" belongs to the class "ManualWorker".
# Fever belongs to symptoms and can be a symptom of Flight (presumably an error in the original text, intended to refer to Fleeing or some other related concept).
# The instance "Fisherman" belongs to the class (or classes) "ManualWorker".
# A headache belongs to the category of pain and can be a symptom of a flea infestation.
# Italy belongs to the category of countries.
# France belongs to the class of Countries.
# Friendly belongs to the class CharacterTrait.
# The concept of GoodHearted belongs to the category of character traits.
# The instance Insulin belongs to classes that are related to injections and helps with health conditions related to diabetes.
# The instance Knife is a member of the classes KitchenTool.
# Lactose Allergy belongs to Food Allergies.
# Leo belongs to the category of adults.
# He works as a waiter.
# His age is 23 years old.
# He is employed at Riccolo.
# The Waiter instance belongs to the classes of Gastronomy Worker.
# LungCancer belongs to the class of diseases known as Cancer.
# It is associated with two symptoms: ShortnessOfBreath and ChestPain.
# The instance 'Mechanic' belongs to the class or classes 'Technical Worker'.
# The instance Miner belongs to one or more classes: Manual Worker.
# The Mixer instance belongs to one or more of the following classes: KitchenTool.
# A musician belongs to the category of creative workers.
# A nurse belongs to the class of health workers.
# The instance Oven belongs to one or more classes: KitchenTool.
# The concept of Painkiller belongs to the category of Pills.
# PeanutAllergy is an instance that belongs to one or more classes including NutAllergies.
#
# It also has a property called cannotEat, which specifies that it relates to Peanuts.
# The instance Peanuts belongs to the class Nuts.
# The instance Plaster belongs to the class MedicalTool.
# The instance Scalpel belongs to one or more of the following classes: MedicalTool.
# A SchoolTeacher is a type of teacher.
# A scientist belongs to the category of knowledge workers.
# SkinCancer belongs to the class of diseases known as Cancer.
# It is associated with two symptoms: Itching and Rash.
# The Syringe instance belongs to one or more instances of the class MedicalTool.
# VitaminC belongs to the class of vitamins.
# UniversityTeacher belongs to the class Teacher.
# VitaminCDeficiency belongs to the class VitaminDeficiency.
# A vocational qualification belongs to the category of education levels and requires an educational level equivalent to high school.
# WalnutAllergy is an instance that belongs to one or more classes known as NutAllergies.
# It has a property called cannotEat, and its value for this property is Walnuts.
# Walnuts belongs to the classes of Nuts.
# The instance Writer belongs to the class CreativeWorker.

# %%
#Print Created scenarios from Story
final_state["scenarios"]
# Out:
# ['Jack just turned 235 years old and is celebrating his birthday with his family.',
#  'Despite being a self-promoter, many people consider Jack a reserved person.',
#  'Jack has asthma that makes it difficult for him to walk far.',
#  'Jack brought medication (specifically antihistamine pills) to manage his asthma symptoms.',
#  "Jack's family is visiting the city of Quito in Ecuador.",
#  'La Virgen del Panecillo, a landmark, overlooks Quito from a tall hill.',
#  'Quito has relatively flat terrain and is easy to walk through.']

# %%
#Print Updated scenarios from Story
final_state["updated_scenarios"]
# Out:
# ['Jack just turned 67 years old and is celebrating his birthday with his family.',
#  'Despite being a self-promoter, many people consider Jack an Adventurous person.',
#  'Jack has asthma that makes it difficult for him to walk far.',
#  'Jack brought an Asthma Inhaler to manage his asthma symptoms.',
#  "Jack's family is visiting the city of Quito in Ecuador.",
#  'La Virgen del Panecillo, a landmark, overlooks Quito from a tall hill.',
#  'LaVirgenDelPanecillo is located on a FlatTerrain in the city of Quito.']

# %%
#Print Final fixed Story
print(final_state["fixed_story"])
# Out:
# Here's the rewritten story with the inconsistencies corrected:
#
# Jack and his family are celebrating his birthday, Jack just turned 67 years old. Jack loves talking about himself and everything he has done in his life, that's why many people would consider Jack an Adventurous person. This year, Jack’s family decided to visit the beautiful city of Quito, famous for its landmark La Virgen del Panecillo, which overlooks the city from a tall hill. Since the city has relatively flat terrain and is easy to walk through, Jack enjoys strolling through the streets without any trouble. It's quite convenient, because Jack can't walk very far due to his asthma. Luckily, Jack brought an Asthma Inhaler to manage his asthma symptoms.
#
# I made minimal changes to preserve the original story's style and narrative flow while correcting the inconsistencies.

# %%
#Print reasoning etc from fixing scenarios function (Check explantion & ontology used to figure out llm reasoning)
reasoning_data = final_state["results"]
reasoning_data
# Out:
# [{'step': 1,
#   'original': 'Jack just turned 67 years old and is celebrating his birthday with his family.',
#   'updated': 'Jack just turned 67 years old and is celebrating his birthday with his family.',
#   'consistency': 'Consistent',
#   'ontology_used': 'John belongs to the class of Adults and has the following properties:\n- He is the parent of Anna.\n- He is married to Amira.\n- His age is 34 years old.\n\nLeo belongs to the category of adults.\nHe works as a waiter.\nHis age is 23 years old.\nHe is employed at Riccolo.\n\nThe Elder class is defined as follows:\n\nIt is a subclass of Thing.\nIt is equivalent to both Person and hasAge with two conditions:\n- The age must be at least 67 years old.\n- The age must be no more than 110 years old.\n\nLifeEvent is a class that inherits from two parent classes:\n\n* It is an Event.\n* It has a participant, and at least one of its participants must be a Person.\n\nJason belongs to the class Adult and has a child named Amelie.',
#   'llm_raw_output': 'Consistency: Consistent\n\nUpdated scenario: Jack just turned 67 years old and is celebrating his birthday with his family.\n\nExplanation:\n1. Ontology: "The Elder class ... hasAge with two conditions: ... The age must be at least 67 years old." Since Jack\'s age meets this condition, he can be classified as an Elder.\n2. No additional information from the ontology context or story so far was needed to determine consistency in this scenario.',
#   'explanation': '1. Ontology: "The Elder class ... hasAge with two conditions: ... The age must be at least 67 years old." Since Jack\'s age meets this condition, he can be classified as an Elder.\n2. No additional information from the ontology context or story so far was needed to determine consistency in this scenario.',
#   'story_so_far': 'Jack just turned 67 years old and is celebrating his birthday with his family.'},
#  {'step': 2,
#   'original': 'Despite being a self-promoter, many people consider Jack a Reserved person.',
#   'updated': 'Despite being a self-promoter, many people consider Jack an Adventurous person.',
#   'consistency': 'Inconsistent',
#   'ontology_used': 'The instance "Reserved" belongs to the class(es) of character traits and implies that an individual with this trait will:\n\n- Hate meeting people\n- Hate talking\n\nThe actor belongs to the creative worker category.\n\nA musician belongs to the category of creative workers.\n\nThe instance Adventurous belongs to one or more classes and implies that the entity it describes loves traveling.\n\nRiccolo belongs to the class of Restaurant.',
#   'llm_raw_output': 'Consistency: Inconsistent\n\nUpdated scenario: Despite being a self-promoter, many people consider Jack an Adventurous person.\n\nExplanation:\n1. Ontology: "The instance \'Reserved\' belongs to the class(es) of character traits and implies that an individual with this trait will: - Hate meeting people - Hate talking". The story so far describes Jack as a self-promoter, which suggests he likes promoting himself (implying he doesn\'t hate talking), making him incompatible with being Reserved.\n2. I changed "Reserved" to "Adventurous", which implies that an individual with this trait loves traveling, aligning with the idea of celebrating his birthday with family, possibly implying a love for hosting or socializing. This is a minimal, natural fix preserving intended meaning.',
#   'explanation': '1. Ontology: "The instance \'Reserved\' belongs to the class(es) of character traits and implies that an individual with this trait will: - Hate meeting people - Hate talking". The story so far describes Jack as a self-promoter, which suggests he likes promoting himself (implying he doesn\'t hate talking), making him incompatible with being Reserved.\n2. I changed "Reserved" to "Adventurous", which implies that an individual with this trait loves traveling, aligning with the idea of celebrating his birthday with family, possibly implying a love for hosting or socializing. This is a minimal, natural fix preserving intended meaning.',
#   'story_so_far': 'Jack just turned 67 years old and is celebrating his birthday with his family.\nDespite being a self-promoter, many people consider Jack an Adventurous person.'},
#  {'step': 3,
#   'original': 'Jack has asthma that makes it difficult for him to walk far.',
#   'updated': '',
#   'consistency': 'Consistent',
#   'ontology_used': 'Asthma is classified as a Health Condition.\n\nIt can be treated with Asthma Inhaler medication.\n\nSymptoms associated with it include Fatigue, Shortness Of Breath, Chest Pain, and Coughing.\n\nShortnessOfBreath is defined as a symptom that belongs to the class of Symptoms.\n\nIt can be a symptom of Anxiety, Asthma, and LungCancer.\n\nFlew belongs to the class of Disease.\nIt comes with symptoms including: \n- RunnyNose\n- Sneezing\n- Coughing\n- Fever\n- Headache\n\nCoughing belongs to one or more classes called Symptoms.\nCoughing can be a symptom of either Asthma or Flew.\n\nAsthma Inhaler belongs to the category of devices that are used for inhalation. It is associated with treating asthma.',
#   'llm_raw_output': 'Consistency: Consistent\n\nUpdated scenario: \nJack has asthma that makes it difficult for him to walk far.\n\nExplanation:\n1. Ontology context states "Asthma is classified as a Health Condition" and "Symptoms associated with [Asthma] include Fatigue, Shortness Of Breath, Chest Pain, and Coughing". Jack having Asthma aligns with these facts.\n2. There\'s no information about Jack being unable to walk far in the ontology context; we\'re looking at how his age affects this scenario. However, since there are no domain or range restrictions on age for Asthma, having asthma is consistent regardless of age.\n3. Ontology also states that "Coughing belongs to one or more classes called Symptoms" and Jack having asthma implies he can have coughing as a symptom according to ontology context, supporting the scenario\'s consistency.',
#   'explanation': '1. Ontology context states "Asthma is classified as a Health Condition" and "Symptoms associated with [Asthma] include Fatigue, Shortness Of Breath, Chest Pain, and Coughing". Jack having Asthma aligns with these facts.\n2. There\'s no information about Jack being unable to walk far in the ontology context; we\'re looking at how his age affects this scenario. However, since there are no domain or range restrictions on age for Asthma, having asthma is consistent regardless of age.\n3. Ontology also states that "Coughing belongs to one or more classes called Symptoms" and Jack having asthma implies he can have coughing as a symptom according to ontology context, supporting the scenario\'s consistency.',
#   'story_so_far': 'Jack just turned 67 years old and is celebrating his birthday with his family.\nDespite being a self-promoter, many people consider Jack an Adventurous person.\nJack has asthma that makes it difficult for him to walk far.'},
#  {'step': 4,
#   'original': 'Jack brought inhalation medicine (specifically, antihistamine pills) to manage his asthma symptoms.',
#   'updated': 'Jack brought an Asthma Inhaler to manage his asthma symptoms.',
#   'consistency': 'Inconsistent',
#   'ontology_used': 'The instance Antihistamine belongs to one or more classes: Pills.\n\nInhalation is a subclass of Medication.\n\nAsthma Inhaler belongs to the category of devices that are used for inhalation. It is associated with treating asthma.\n\nThe class Allergies is defined as follows:\n\nIt is a type of Disorder.\nIt has a medication, which is an Antihistamine, with an unknown restriction regarding this medication.\n\nAsthma is classified as a Health Condition.\n\nIt can be treated with Asthma Inhaler medication.\n\nSymptoms associated with it include Fatigue, Shortness Of Breath, Chest Pain, and Coughing.',
#   'llm_raw_output': 'Consistency: Inconsistent\n\nUpdated scenario: Jack brought an Asthma Inhaler to manage his asthma symptoms.\n\nExplanation:\n1. Ontology: "Asthma Inhaler belongs to the category of devices that are used for inhalation" and "Inhalation is a subclass of Medication". The scenario initially stated that Jack brought "inhalation medicine (specifically, antihistamine pills)", which implies an incorrect type of medication for asthma.\n2. I changed "an Asthma Inhaler" to replace the original scenario. This fix is minimal and preserves the intended meaning of managing Jack\'s asthma symptoms with a proper device, as per the ontology context.',
#   'explanation': '1. Ontology: "Asthma Inhaler belongs to the category of devices that are used for inhalation" and "Inhalation is a subclass of Medication". The scenario initially stated that Jack brought "inhalation medicine (specifically, antihistamine pills)", which implies an incorrect type of medication for asthma.\n2. I changed "an Asthma Inhaler" to replace the original scenario. This fix is minimal and preserves the intended meaning of managing Jack\'s asthma symptoms with a proper device, as per the ontology context.',
#   'story_so_far': 'Jack just turned 67 years old and is celebrating his birthday with his family.\nDespite being a self-promoter, many people consider Jack an Adventurous person.\nJack has asthma that makes it difficult for him to walk far.\nJack brought an Asthma Inhaler to manage his asthma symptoms.'},
#  {'step': 5,
#   'original': "Jack's family is visiting the city of Quito in Ecuador.",
#   'updated': "Jack's family is visiting the city of Quito in Ecuador.",
#   'consistency': 'Consistent',
#   'ontology_used': 'Quito belongs to one or more classes of City.\nQuito is located in Ecuador.\nThe car-to-person ratio in Quito is 511.0 per person.\nThe population of Quito is approximately 2,342,000 people.\n\nEcuador belongs to the class of Countries.\n\nLaVirgenDelPanecillo is defined as follows:\nIt belongs to the class(es) Landmark.\nIt is located in Quito.\nIt has a building height of 41.0 units.\nIt was built in the year 1975.\n\nSpain belongs to the class of countries.\n\nA City is a Place.\nA City must be located in some Country.',
#   'llm_raw_output': 'Consistency: Consistent\n\nUpdated scenario: Jack\'s family is visiting the city of Quito in Ecuador.\n\nExplanation:\n1. Ontology: "A City must be located in some Country" and "Quito is located in Ecuador". This establishes a connection between Quito (a City) and Ecuador (a Country).\n2. The story so far does not provide any information that would contradict this new scenario.\n3. There are no other relevant ontology statements that could affect the consistency of this specific scenario.\n\nNote: Since there\'s no inconsistency, no changes were made to the original scenario.',
#   'explanation': '1. Ontology: "A City must be located in some Country" and "Quito is located in Ecuador". This establishes a connection between Quito (a City) and Ecuador (a Country).\n2. The story so far does not provide any information that would contradict this new scenario.\n3. There are no other relevant ontology statements that could affect the consistency of this specific scenario.\n\nNote: Since there\'s no inconsistency, no changes were made to the original scenario.',
#   'story_so_far': "Jack just turned 67 years old and is celebrating his birthday with his family.\nDespite being a self-promoter, many people consider Jack an Adventurous person.\nJack has asthma that makes it difficult for him to walk far.\nJack brought an Asthma Inhaler to manage his asthma symptoms.\nJack's family is visiting the city of Quito in Ecuador."},
#  {'step': 6,
#   'original': 'La Virgen del Panecillo, a landmark, overlooks Quito from a tall hill.',
#   'updated': '',
#   'consistency': 'Consistent',
#   'ontology_used': 'LaVirgenDelPanecillo is defined as follows:\nIt belongs to the class(es) Landmark.\nIt is located in Quito.\nIt has a building height of 41.0 units.\nIt was built in the year 1975.\n\nQuito belongs to one or more classes of City.\nQuito is located in Ecuador.\nThe car-to-person ratio in Quito is 511.0 per person.\nThe population of Quito is approximately 2,342,000 people.\n\nThe RedRocksAmphitheatre instance belongs to a category known as Landmark.\nIt is located in Denver.\nIts building height is 1970.0 units.\nIt was built in the year 1941.\n\nThe Eiffel Tower is classified as a Landmark.\nIt is located in Paris.\nIts building height is 330.0 units.\nIt was built in the year 1887.\n\nThe DuomoDiFirenze instance belongs to one or more classes known as Landmark.\nIt is located in Florence.\nIts building height is 115.0 units.\nIt was built in the year 1296.',
#   'llm_raw_output': 'Consistency: Consistent\n\nExplanation:\n1. Ontology: "LaVirgenDelPanecillo ... belongs to the class(es) Landmark" and "It is located in Quito". Since La Virgen del Panecillo is a landmark and it\'s in Quito, its location aligns with its classification.\n2. Additionally, we used the fact that "Quito ... is located in Ecuador", which indirectly supports the consistency of the scenario as La Virgen del Panecillo being in Quito (a city in Ecuador) fits within the ontology context.\n\nUpdated scenario: \nLa Virgen del Panecillo, a landmark, overlooks Quito from a tall hill.',
#   'explanation': '1. Ontology: "LaVirgenDelPanecillo ... belongs to the class(es) Landmark" and "It is located in Quito". Since La Virgen del Panecillo is a landmark and it\'s in Quito, its location aligns with its classification.\n2. Additionally, we used the fact that "Quito ... is located in Ecuador", which indirectly supports the consistency of the scenario as La Virgen del Panecillo being in Quito (a city in Ecuador) fits within the ontology context.',
#   'story_so_far': "Jack just turned 67 years old and is celebrating his birthday with his family.\nDespite being a self-promoter, many people consider Jack an Adventurous person.\nJack has asthma that makes it difficult for him to walk far.\nJack brought an Asthma Inhaler to manage his asthma symptoms.\nJack's family is visiting the city of Quito in Ecuador.\nLa Virgen del Panecillo, a landmark, overlooks Quito from a tall hill."},
#  {'step': 7,
#   'original': 'Quito has relatively flat terrain and many buildings have one or more FlatTerrains nearby in Quito.',
#   'updated': 'LaVirgenDelPanecillo is located on a FlatTerrain in the city of Quito.',
#   'consistency': 'Inconsistent',
#   'ontology_used': 'Quito belongs to one or more classes of City.\nQuito is located in Ecuador.\nThe car-to-person ratio in Quito is 511.0 per person.\nThe population of Quito is approximately 2,342,000 people.\n\nLaVirgenDelPanecillo is defined as follows:\nIt belongs to the class(es) Landmark.\nIt is located in Quito.\nIt has a building height of 41.0 units.\nIt was built in the year 1975.\n\nThe class FlatTerrain is a subclass of Terrain.\n\nEcuador belongs to the class of Countries.\n\nMountainousTerrain is a type of terrain.\n\nIt is also characterized by having a noise level that is quiet.',
#   'llm_raw_output': 'Consistency: Inconsistent\n\nUpdated scenario: LaVirgenDelPanecillo is located on a FlatTerrain in the city of Quito.\n\nExplanation:\n1. Ontology: "The car-to-person ratio in Quito is 511.0 per person" implies that the terrain is likely not completely flat, as cities with very high population densities like this are often built on hilly or mountainous terrain.\n2. However, we do know that LaVirgenDelPanecillo, a landmark in Quito, has a building height of 41.0 units and was built in 1975 (implying some structural support is necessary).\n3. Since LaVirgenDelPanecillo exists on a hill overlooking Quito, it\'s reasonable to assume that the terrain nearby, including where buildings might be constructed, could also have FlatTerrains nearby.\n4. This minimal change preserves meaning and story flow by not contradicting other established facts about Quito\'s terrain or landmarks.',
#   'explanation': '1. Ontology: "The car-to-person ratio in Quito is 511.0 per person" implies that the terrain is likely not completely flat, as cities with very high population densities like this are often built on hilly or mountainous terrain.\n2. However, we do know that LaVirgenDelPanecillo, a landmark in Quito, has a building height of 41.0 units and was built in 1975 (implying some structural support is necessary).\n3. Since LaVirgenDelPanecillo exists on a hill overlooking Quito, it\'s reasonable to assume that the terrain nearby, including where buildings might be constructed, could also have FlatTerrains nearby.\n4. This minimal change preserves meaning and story flow by not contradicting other established facts about Quito\'s terrain or landmarks.',
#   'story_so_far': "Jack just turned 67 years old and is celebrating his birthday with his family.\nDespite being a self-promoter, many people consider Jack an Adventurous person.\nJack has asthma that makes it difficult for him to walk far.\nJack brought an Asthma Inhaler to manage his asthma symptoms.\nJack's family is visiting the city of Quito in Ecuador.\nLa Virgen del Panecillo, a landmark, overlooks Quito from a tall hill.\nLaVirgenDelPanecillo is located on a FlatTerrain in the city of Quito."}]

# %%
import json

# Create a combined export dictionary
export_data = {
    "original_story": final_state.get("story", ""),
    "scenarios": final_state.get("scenarios", []),
    "updated_scenarios": final_state.get("updated_scenarios", []),
    "fixed_story": final_state.get("fixed_story", ""),
    "reasoning_results": final_state.get("results", []),
}

# Save it as JSON
with open("story+reasoning_output.json", "w", encoding="utf-8") as f:
    json.dump(export_data, f, indent=2, ensure_ascii=False)

print("Saved everything to json file")
# Out:
# Saved everything to json file

# %%
all_runs = []

for i in range(10):
    print(f"running {i+1}/10")
    final_state = graph.invoke(initial_state)

    all_runs.append({
        "scenarios": final_state.get("scenarios", []),
        "updated_scenarios": final_state.get("updated_scenarios", []),
        "fixed_story": final_state.get("fixed_story", "")
    })


export_data = {
    "original_story": story,
    "iterations": all_runs
}

with open("final_story5_10runs.json", "w", encoding="utf-8") as f:
    json.dump(export_data, f, indent=2, ensure_ascii=False)
# Out:
# running 1/10
# running 2/10
# running 3/10
# running 4/10
# running 5/10
# running 6/10
# running 7/10
# running 8/10
# running 9/10
# running 10/10
